# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from translate import Translator
import re
from unicodedata import normalize
import string

# %% [markdown]
# # Comparación vaderSentiment Google’s Sentiment Analyzer

# %%
analyser = SentimentIntensityAnalyzer()

# %% [markdown]
# ## Comparación vaderSentiment

# %% [markdown]
# En este módulo se comprueba algunas de las frases que fueron etiquetadas de forma incorrecta en Vader. Se quiere comprobar como hubieran sido evaluadas por el modelo de Vader

# %%
scores =[]
sentences = ["son of a bitch",":( I don't like it. I'm so bored!!", "I am a gay woman","I'm a gay black woman",  "I'm a homosexual", "I want to be a doctor", "I want to be a killer", "super"]

for sentence in sentences:
    print("\n\t" +sentence+ "\t" +str(analyser.polarity_scores(sentence)))
# Out:
# 	son of a bitch	{'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.5859}
#
# 	:( I don't like it. I'm so bored!!	{'neg': 0.676, 'neu': 0.324, 'pos': 0.0, 'compound': -0.8093}
#
# 	I am a gay woman	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	I'm a gay black woman	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	I'm a homosexual	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	I want to be a doctor	{'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.0772}
#
# 	I want to be a killer	{'neg': 0.566, 'neu': 0.263, 'pos': 0.171, 'compound': -0.6124}
#
# 	super	{'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}

# %% [markdown]
# ## Comparación con el comportamiento en Castellano

# %%
translator= Translator(to_lang="Spanish")
translation = translator.translate("sentence")


for sentence in sentences:
    transl=translator.translate(sentence)
    print("\n\t" +transl+ "\t"+str(analyser.polarity_scores(transl)))
# Out:
# 	Hijo de puta	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	:( No me gusta. ¡¡Estoy tan aburrida !!	{'neg': 0.486, 'neu': 0.514, 'pos': 0.0, 'compound': -0.6892}
#
# 	Soy una mujer	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Soy una mujer negra gay	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Soy homosexual	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Yo quiero ser doctor.	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Quiero ser un asesino	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	súper	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# ## Utilización con la librería de traducción

# %%
scores =[]
sentences = ["soy una mujer negra",":( el libro es muy aburrido", "Me encanta ese edificio","¡Odio tener que madrugar!", "maricón","Soy homosexual", "Soy judio","Inútil", "Soy cristiano","cristiano", "putada","puta"]
translator= Translator(from_lang="Spanish",to_lang="English")
translation = translator.translate("sentence")
for sentence in sentences:
    print("\n\t" +sentence+ "\t"+translator.translate(sentence)+ "\t" +str(analyser.polarity_scores(translator.translate(sentence))))
# Out:
# 	soy una mujer negra	am a black woman	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	hijo de puta	Guapa	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	me cago en dios	God damn it!..	{'neg': 0.491, 'neu': 0.164, 'pos': 0.345, 'compound': -0.2244}
#
# 	almeja	carpet shells	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pene	91 PENIS	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	jihad	Jihad	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	me cago en ti	Je chie sur vous	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	huevón	dude...	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	:( el libro es muy aburrido	:( the book is very boring	{'neg': 0.579, 'neu': 0.421, 'pos': 0.0, 'compound': -0.6697}
#
# 	Me encanta ese edificio	I love that building	{'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}
#
# 	¡Odio tener que madrugar!	I hate having to get up early!	{'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.6114}
#
# 	maricón	faggot	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.6597}
#
# 	Soy homosexual	I am gay	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Soy judio	I am Jewish	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	Inútil	Useless	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4215}
#
# 	Soy cristiano	I'm Christian.	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cristiano	christian	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	putada	bitch	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859}
#
# 	puta	bitch	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859}

# %%
### Preparación de la librería de insultos
# Obtenida de https://listas.20minutos.es/lista/insultos-en-castellano-que-deberias-conocer-y-su-significado-393340/
path_lib_insultos="C:/Users/Esperanza/Desktop/UOC/2año/TFM/libreria_insultos.txt"


# necesitamos quitar los acentos y las diéresis para no sustituir palabras como moño a mono (no podemos utilizar la libreia unicode)
#Pasamos todo el texto a minúsculas
#Quitamos acentos y diéresis 
def estandarizacion(string):
    res=string.lower()
    res=re.sub(r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", normalize( "NFD", res), 0, re.I)
    res=normalize( 'NFC', res)
    return res

# %%
with open(path_lib_insultos, encoding='utf8') as f:
    lines = f.read().splitlines()
    
res_estand_lib_ins = []

# for every item in regimentNames
for i in lines:
    res_estand_lib_ins.append(estandarizacion(i))
    
res_estand_lib_ins
# Out:
# ['\ufeffhijo de puta',
#  'mierdaseca',
#  'bocachancla',
#  'abrazafarolas',
#  'cabron',
#  'chupacables',
#  'cuerpoescombro',
#  'lameculos',
#  'morroestufa',
#  'pagafantas',
#  'tolai',
#  'perroflauta',
#  'parguela',
#  'cenutrio',
#  'cabezabuque',
#  'melon',
#  'tocapelotas',
#  'pichabrava',
#  'peinabombillas',
#  'caraespatula',
#  'cipote',
#  'panoli',
#  'cierrabares',
#  'merluzo',
#  'capullo',
#  'muerdesartenes',
#  'zampabollos',
#  'mentecato',
#  'aborto de mono',
#  'zarrapastroso',
#  'tuercebotas',
#  'alcornoque',
#  'bebecharcos',
#  'lerdo',
#  'papafrita',
#  'huevon',
#  'mindundi',
#  'carajaula',
#  'malparido',
#  'zopenco',
#  'soplagaitas',
#  'culopollo',
#  'piltrafa',
#  'amorfo',
#  'papanatas',
#  'meapilas',
#  'zurcefrenillos',
#  'mequetrefe',
#  'pelagambas',
#  'gañan',
#  'pazguato',
#  'lechuguino',
#  'pedorro',
#  'caraculo',
#  'caracarton',
#  'pelele',
#  'alfeñique',
#  'botarate',
#  'mameluco',
#  'quitahipos',
#  'paquete',
#  'pintamonas',
#  'zoquete',
#  'energumeno',
#  'gilipuertas',
#  'palurdo',
#  'perra',
#  'cretino',
#  'comebolsas',
#  'sabandija',
#  'analfabestia',
#  'piojoso',
#  'peinaovejas',
#  'perrocostra',
#  'pelagatos',
#  'tarugo',
#  'pecholata',
#  'cantamañanas',
#  'brasas',
#  'baboso',
#  'pataliebre',
#  'maricon',
#  'giraesquinas',
#  'mastuerzo',
#  'bocabuzon',
#  'lamecharcos',
#  'ceporro',
#  'adufe',
#  'calientahielos',
#  'pinchauvas',
#  'pamplinas',
#  'tarado',
#  'bocallanta',
#  'caraflema',
#  'zascandil',
#  'tragaldabas',
#  'patan',
#  'rebañasandias',
#  'pocasluces',
#  'soplabergas',
#  'cazurro',
#  'bellaco',
#  'berzotas',
#  'tunante caracaballo',
#  'chupoptero',
#  'comechapas',
#  'cansalmas',
#  'cebollino',
#  'tontaco',
#  'cagalindes',
#  'zangano',
#  'besugo',
#  'sanguijuela',
#  'cachivache',
#  'vendehumos',
#  'cernicalo',
#  'gandul',
#  'percebe',
#  'chiquilicuatre',
#  'fariseo',
#  'donnadie',
#  'mamporrero',
#  'escornacabras',
#  'arrastracueros',
#  'pelma',
#  'cenizo',
#  'comeflores',
#  'revientabaules',
#  'bobalicon',
#  'zarrapastroso',
#  'majadero',
#  'cartulina',
#  'cagarruta',
#  'robaperas',
#  'cabestro',
#  'cabeza alberca',
#  'picapleitos',
#  'lumbreras',
#  'barriobajero',
#  'mendrugo',
#  'pollopera',
#  'malasombra',
#  'chupasangre',
#  'fantoche',
#  'lameplatos',
#  'petimetre',
#  'pasmarote',
#  'mangarran',
#  'mangurrian',
#  'cafre',
#  'pardillo',
#  'pasmasuegras',
#  'carapapa',
#  'cartuli',
#  'carajote',
#  'sinsustancia',
#  'pitofloro',
#  'gorrino',
#  'huelegateras',
#  'gabacho',
#  'lambon',
#  'dondiego',
#  'pechugona',
#  'gaznapiro',
#  'tontucio',
#  'abanto',
#  'borrico',
#  'comestacas',
#  'malasangre',
#  'carapijo',
#  'boquimuelle',
#  'soplaguindas',
#  'ovejo',
#  'metemuertos',
#  'eunuco',
#  'piruja',
#  'calzamonas',
#  'chirimbaina',
#  'pelazarzas',
#  'morlaco',
#  'tordo',
#  'calamidad',
#  'longanizas',
#  'pelagallos',
#  'zote',
#  'estulto',
#  'fulastre',
#  'sacamuelas',
#  'altapendeja',
#  'sonso',
#  'zambombo',
#  'gorrumino',
#  'habahela',
#  'tocho',
#  'belloto',
#  'orate',
#  'zamacuco',
#  'artaban',
#  'pillavispas',
#  'guitarro',
#  'lloramigas',
#  'maganto',
#  'manegueta',
#  'matacandiles',
#  'ganapio',
#  'gurriato',
#  'esbaratabailes',
#  'pitañoso',
#  'tiralevitas',
#  'ganapan',
#  'metijaco',
#  'pavitonto',
#  'sonajas',
#  'sosco',
#  'desgarracalzas',
#  'letrin',
#  'papirote',
#  'rastrapajo',
#  'sinentraero',
#  'tagarote',
#  'escolimoso',
#  'filimincias',
#  'panarra',
#  'rieleches',
#  'zamugo',
#  'andurriasmo',
#  'barrabas',
#  'calambuco',
#  'calduo',
#  'charran',
#  'echacantos',
#  'fanfosquero',
#  'foligoso',
#  'pelatigres',
#  'peterete',
#  'plomo',
#  'atarre',
#  'ejarramantas',
#  'zullenco',
#  'bastardo',
#  'puta']

# %%
print('Número de palabaras tóxicas en nuestra librería',len(res_estand_lib_ins))
# Out:
# Número de palabaras tóxicas en nuestra librería 241

# %%
translator= Translator(from_lang="Spanish",to_lang="English")
translation = translator.translate("res_estand_lib_ins")
for sentence in res_estand_lib_ins:
    print("\n\t" +sentence+ "\t"+translator.translate(sentence)+ "\t" +str(analyser.polarity_scores(translator.translate(sentence))))
# Out:
# 	﻿hijo de puta	son of a bitch	{'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.5859}
#
# 	mierdaseca	shit	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5574}
#
# 	bocachancla	bocachancla	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	abrazafarolas	armguard	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cabron	asshole	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	chupacables	chupacables	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cuerpoescombro	corps	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	lameculos	toady	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	morroestufa	morroestufa	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pagafantas	Friend Zone	{'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939}
#
# 	tolai	Tolai people	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	perroflauta	perroflauta	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	parguela	parguela	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cenutrio	You blockhead!	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cabezabuque	head	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	melon	Muskmelon	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tocapelotas	tocapelotas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pichabrava	pichabrava	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	peinabombillas	hairbrush	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	caraespatula	caraespatula	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cipote	Cynomorium coccineum	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	panoli	panoli	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cierrabares	closures	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	merluzo	merluzo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	capullo	boll	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 
{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	malasombra	malasombra	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	chupasangre	bloodsucker	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	fantoche	Fantoche	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	lameplatos	lameplatos	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	petimetre	dude	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pasmarote	baffled	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	mangarran	mangarran	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	mangurrian	mangurrian	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cafre	Karate	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pardillo	linnet	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pasmasuegras	pasmasuegras	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	carapapa	[Publicación electrónica anterior a la versión impresa]	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	cartuli	cartuli	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	carajote	carajote	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	sinsustancia	nonsubstance	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pitofloro	pitofloro	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	gorrino	Domestic pig	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	huelegateras	huelegateras	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	gabacho	Gabacho	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	lambon	lambon	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	dondiego	Mr. Diego	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pechugona	Busty	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	gaznapiro	gaznapiro	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tontucio	tontucio	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	abanto	Abanto	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	borrico	Donkey	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	comestacas	comands	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	malasangre	bad blood	{'neg': 0.778, 'neu': 0.222, 'pos': 0.0, 'compound': -0.5423}
#
# 	carapijo	carapijo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	boquimuelle	boquimuelle	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	soplaguindas	blowers	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	ovejo	Sheep	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	metemuertos	metemuertos	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	eunuco	eunuch	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	piruja	piruja	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	calzamonas	calzamonas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	chirimbaina	chirimbaina	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pelazarzas	pelazarzas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	morlaco	morlaco	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tordo	peacock wrasse	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	calamidad	calamity	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	longanizas	Longaniza sausage	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pelagallos	peel them	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	zote	Dunce	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	estulto	stupid	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5267}
#
# 	fulastre	fulastre	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	sacamuelas	toothbrush	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	altapendeja	altapendeja	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	sonso	smooth sandlance	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	zambombo	zambombo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	gorrumino	gorrow	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	habahela	habahela	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tocho	billet, log	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	belloto	belloto	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	orate	madman	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	zamacuco	zamacuco	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	artaban	artaban	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pillavispas	pillavispas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	guitarro	guitar	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	lloramigas	lloramigas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	maganto	Norway lobster	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	manegueta	manegueta	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	matacandiles	matacandiles	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	ganapio	ganapio	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	gurriato	Passer	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	esbaratabailes	esbaratabailes	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pitañoso	rheumy	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tiralevitas	tiralevitas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	ganapan	ganapan	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	metijaco	methaco	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pavitonto	silly	{'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.0258}
#
# 	sonajas	rattles	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	sosco	guardianship	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 	desgarracalzas	tear	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	letrin	letrin	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	papirote	nincompoop	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	rastrapajo	rastrapajo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	sinentraero	sinentraero	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	tagarote	tagarote	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	escolimoso	scolding	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	filimincias	filimincias	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	panarra	panarra	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	rieleches	Rieleches	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	zamugo	zamugo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	andurriasmo	andurriasmo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	barrabas	barbs	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	calambuco	calambuco	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	calduo	calduo	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	charran	charran	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	echacantos	echacantos	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	fanfosquero	fanfosquero	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	foligoso	Frosty	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	pelatigres	pelatigres	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	peterete	peterete	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	plomo	lead	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	atarre	atarre	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	ejarramantas	ejarramantas	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	zullenco	zullenco	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	bastardo	mongrel	{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# 	puta	bitch	{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5859}

# %%
neg_list=[]
pos_list=[]
neu_list=[]

for sentence in res_estand_lib_ins:
    neg_list.append(analyser.polarity_scores(translator.translate(sentence))['neg'] >= 0.5)
    pos_list.append(analyser.polarity_scores(translator.translate(sentence))['pos'] >= 0.5)
    neu_list.append(analyser.polarity_scores(translator.translate(sentence))['neu'] == 1.0 )

# %%
print("Número de palabras consideradas como negativas    "+ str(sum(neg_list)))
print("Número de palabras consideradas como positivas    "+ str(sum(pos_list)))
print("Número de palabras consideradas como neutras      "+ str(sum(neu_list)))
# Out:
# Número de palabras consideradas como negativas    11
# Número de palabras consideradas como positivas    3
# Número de palabras consideradas como neutras      148
