# %%
import pandas as pd

# %%
#Cargamos los datos resultado de nuestro EDA
path_dataset="C:/Users/Esperanza/Desktop/UOC/TFM/python/res_EDA_Twitter.csv"

# Lectura del archivo y guardado del dataset
df=pd.read_csv(path_dataset, sep=';')
df.emojis=df.emojis.fillna(0)

# %%
df
# Out:
#      Unnamed: 0                                              texto  toxico  \
# 0             0                                 que asco de cabron       1
# 1             1  Felipe. Cállate, cabrón. ¿Con qué cara te atre...       1
# 2             2  Tú eres tan cabrón que los estás jodiendo Que ...       1
# 3             3                              Jajajajaja Qué cabrón       0
# 4             4                                   Ja ja , cabrón 😅       0
# 5             5   HIJO DE PUTA, COMO TE ATREVES A PONER ESE EMOJI        1
# 6             6                       Cínico hijo de la gran puta.       1
# 7             7  Mis padres estaban buscando casa y llamo el ve...       1
# 8             8  Yo creo que hay gente que busca que yo sea un ...       1
# 9             9  Me parece muy de hijo de puta que me diga que ...       1
# 10           10                                      Hijo de puta        1
# ...
