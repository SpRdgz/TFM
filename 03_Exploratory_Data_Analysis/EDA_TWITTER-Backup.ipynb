# %% [markdown]
# -- Exploratory data analysis--
#
#     Analiza el conjunto de datos con el objetivo de resumir sus características principales, generalmente a través de medios visuales.
#     La finalidad es ver que pueden decirnos los datos más alla del modelado formal o las pruebas de hipótesis
#
#
# Fuente: https://en.wikipedia.org/wiki/Exploratory_data_analysis

# %% [markdown]
# Data Mining de la muestra extraida de Twitter. Es muy probable que con el paso del tiempo debido a la ampliación de necesidades se incremente la muestra.
#
# Al obtener el dataset ya se hicieron algunos pasos de data mining como:
#
# * Supresión de cuentas a las que hace referencia (@XXXX) y aglutinación de múltiples espacios en uno
# * Eliminación de páginas web (http,https y www) (str.replace('http\S+|www.\S+', '', case=False))
# * Eliminación del símbolo # que hace referencia a los hastag
# * Supresión de comentarios duplicados una vez que se elimina todo lo anterior
#
# Este dataset contiene lenguaje tóxico que es el que se está analizando.

# %%
import pandas as pd
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from wordcloud import WordCloud
import re
import numpy as np
from emoji import UNICODE_EMOJI
from nltk import bigrams 

# %matplotlib inline

# %% [markdown]
# # Lectura de la muestra

# %%
df = pd.read_csv("C:/Users/Esperanza/Desktop/UOC/TFM/python/comentarios_toxicos.csv", sep=';',usecols=[0,1])
df.iloc[264,:]
# Out:
# texto     _efs Juego sucio no, barriobajero.
# toxico                                     1
# Name: 264, dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **1) Eliminación de todas las palabras que empiecen por '_' ya que no nos dan información. **
#
# *_Zaragoza_ Cállese burro, lea libros y tuitee menos, botarate. ;1;*

# %%
#Función que elimina la palabra que empiece por el caracter (char) en el texto(text)
def delete_starting_with(text, char):
    text=' '.join(word for word in text.split(' ') if not word.startswith(char))
    return text

# %%
df['texto']=df['texto'].apply(lambda txt: delete_starting_with(txt, '_') )
df['texto']=df['texto'].replace('_','')
df.iloc[264,:]
# Out:
# texto     Juego sucio no, barriobajero.
# toxico                                1
# Name: 264, dtype: object

# %% [markdown]
# **2) Eliminación de las comillas. **
#
# *"""Tú eres tan cabrón que los estás jodiendo"" ""Que pongan el aire más alto así nos infectamos"" ""Estos hijos de puta se tienen que ir a su país"" ""Que esto es España joder"" ""Dentro de poco esto va a estar lleno de ratas y nos vamos a infectar todos"" ""Me están tocando los huevos"""*

# %%
df.iloc[2,:]
# Out:
# texto     "Tú eres tan cabrón que los estás jodiendo" "Q...
# toxico                                                    1
# Name: 2, dtype: object

# %%
df['texto']=df.texto.apply(lambda x: x.replace('\"',''))
df.iloc[2,:]
# Out:
# texto     Tú eres tan cabrón que los estás jodiendo Que ...
# toxico                                                    1
# Name: 2, dtype: object

# %% [markdown]
# # Análisis

# %% [markdown]
# ** Descripción general del dataset**

# %%
#Dimensiones del corpus obtenido de Twitter sobre lenguaje tóxico
print("Número de filas : "+str(df.shape[0]))
print("Número de columnas : "+str(df.shape[1]))
# Out:
# Número de filas : 530
# Número de columnas : 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 2 columns):
# texto     530 non-null object
# toxico    530 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 8.4+ KB

# %% [markdown]
# Donde se puede ver que no hay ningún valor a nulo. gracias a reconocerlos con:

# %%
df[df.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [texto, toxico]
# Index: []

# %% [markdown]
# ** Cuenta del número de signos de admiración en mayúsculas como signo de exaltación. **
#
# *ENTRETÉNME, PAYASO!!!... *

# %%
#Creación de la columna que cuenta el número de veces que aparece un símbolo
df['num_admir']=df.texto.apply(lambda txt: txt.count('!') )

# %%
df.iloc[194,:]
# Out:
# texto        ENTRETÉNME, PAYASO!!!...
# toxico                               1
# num_admir                            3
# Name: 194, dtype: object

# %% [markdown]
# **Cuenta del número de palabras en mayúsculas como signo de exaltación. **
#
# *ENTRETÉNME, PAYASO!!!... *

# %%
regex = r"\B[A-Z]+\b"
frase = "Que Valls será un mierdaseca, que nadie lo discute, pero que está ofreciendo sus votos GRATIS CHABALADA. No he visto todavía a la derecha catalana hacer lo mismo"

# %%
#Búsqueda las palabras en mayúsculas a través de una expresión regular
df['num_may']=df.texto.apply(lambda txt: len(list(re.finditer(regex, txt))) )
#matches = list(re.finditer(regex, frase))
#type(matches)
df.iloc[194,:]
# Out:
# texto        ENTRETÉNME, PAYASO!!!...
# toxico                               1
# num_admir                            3
# num_may                              2
# Name: 194, dtype: object

# %% [markdown]
# **Tokenización de los textos. **

# %%
series_token=df.texto.apply(lambda txt: print(word_tokenize(txt)))
# Out:
# ['que', 'asco', 'de', 'cabron']
# ['Felipe', '.', 'Cállate', ',', 'cabrón', '.', '¿Con', 'qué', 'cara', 'te', 'atreves', 'a', 'hablar', 'sobre', 'construcción', 'de', 'refinerías', '?']
# ['Tú', 'eres', 'tan', 'cabrón', 'que', 'los', 'estás', 'jodiendo', 'Que', 'pongan', 'el', 'aire', 'más', 'alto', 'así', 'nos', 'infectamos', 'Estos', 'hijos', 'de', 'puta', 'se', 'tienen', 'que', 'ir', 'a', 'su', 'país', 'Que', 'esto', 'es', 'España', 'joder', 'Dentro', 'de', 'poco', 'esto', 'va', 'a', 'estar', 'lleno', 'de', 'ratas', 'y', 'nos', 'vamos', 'a', 'infectar', 'todos', 'Me', 'están', 'tocando', 'los', 'huevos']
# ['Jajajajaja', 'Qué', 'cabrón']
# ['Ja', 'ja', ',', 'cabrón', '😅']
# ['HIJO', 'DE', 'PUTA', ',', 'COMO', 'TE', 'ATREVES', 'A', 'PONER', 'ESE', 'EMOJI']
# ['Cínico', 'hijo', 'de', 'la', 'gran', 'puta', '.']
# ['Mis', 'padres', 'estaban', 'buscando', 'casa', 'y', 'llamo', 'el', 'vendedor', 'de', 'la', 'casa', '.', 'Yo', 'cogí', 'el', 'teléfono', 'y', 'empecé', 'a', 'insultarte', '(', 'gilipollas', ',', 'hijo', 'de', 'puta', ')', 'sin', 'motivo', 'aparente', ',', 'era', 'pequeño.Y', 'después', 'mi', 'madre', 'como', 'buena', 'madre', 'gallega', 'me', 'obligó', 'a', 'ir', 'a', 'verlo', 'y', 'disculparme', ',', 'me', 'quería', 'morir', 'de', 'la', 'vergüenza']
# ['Yo', 'creo', 'que', 'hay', 'gente', 'que', 'busca', 'que', 'yo', 'sea', 'un', 'hijo', 'de', 'puta', '.', 'Tengo', 'pruebas', 'eh', ',', 'porque', 'siempre', ',', 'juro', 'que', 'siempre', 'que', 'me', 'porto', 'bien', 'me', 'terminan', 'haciendo', 'x', 'cosa', 'para', 'que', 'me', 'ponga', 'en', 'hijo', 'de', 'mil', 'puta', '.', 'Creo', 'que', 'el', 'problema', 'está', 'en', 'cuando', 'quiero', 'ser', 'buena', 'persona']
# ['Me', 'parece', 'muy', 'de', 'hijo', 'de', 'puta', 'que', 'me', 'diga', 'que', 'esté', 'con', 'la', 'novia', 'y', 'me', 'pida', 'vernos', ',', 'UN', 'HIJO', 'DE', 'PUTA', '.']
# ['Hijo', 'de', 'puta']
# ['Nos', 'estás', 'amenazando', ',', 'mierdaseca', '?']
# ['Los', 'NIÑATOS', 'que', 'reniegan', 'de', 'Ramos', ',', 'son', 'los', 'mismos', 'que', 'idolatran', 'al', 'mierdaseca', 'de', 'Mourinho', ',', 'que', 'echaron', 'al', 'mejor', 'portero', 'del', 'mundo', ',', 'Casillas', '.', 'Aficionados', 'se', 'hacen', 'llamar', '...', '.']
# ['Que', 'Valls', 'será', 'un', 'mierdaseca', ',', 'que', 'nadie', 'lo', 'discute', ',', 'pero', 'que', 'está', 'ofreciendo', 'sus', 'votos', 'GRATIS', 'CHABALADA', '.', 'No', 'he', 'visto', 'todavía', 'a', 'la', 'derecha', 'catalana', 'hacer', 'lo', 'mismo', '.']
# ['Salía', 'del', 'aeropuerto', 'con', 'mis', 'compañeros', 'y', 'un', 'puto', 'guiri', 'de', 'mierda', 'ha', 'dicho', 'low', 'cost', 'airline', ',', 'low', 'cost', '...', 'Y', 'luego', 'algo', 'que', 'no', 'he', 'oído', 'bien', 'y', 'se', 'han', 'reído', 'pero', 'estoy', 'segura', 'de', 'que', 'se', 'refería', 'a', 'que', 'nosotros', 'éramos', 'baratos', 'y', 'de', 'verdad', ',', 'ojalá', 'se', 'tire', 'por', 'un', 'balcón', 'el', 'muy', 'mierdaseca']
# ['Que', 'te', 'pires', 'mierdaseca', '!']
# ['Monedero', ',', 'te', 'ha', 'devorado', 'el', 'personaje', '.', 'Eres', 'un', 'mierdaseca', '.']
# ['no', 'se', 'puede', 'ser', 'más', 'bocachancla', '...']
# ['Yo', 'flipo', ',', 'con', 'lo', 'bocachancla', 'q', 'puede', 'ser', 'la', 'gente', '...']
# ['Ningún', 'bocachancla', 'sin', 'captura', '.']
# ['Pero', 'si', 'no', 'ganasteis', 'vuestro', 'psrtido', 'bocachancla']
# ['El', 'bocachancla', 'tiene', 'implantada', 'en', 'la', 'personalidad', 'la', 'prepotencia', 'por', 'defecto', '...']
# ['Populismo', '?', 'populismo', 'eres', 'tú', ',', 'bocachancla']
# ['Callate', 'bocachancla', ',', 'no', 'hace', 'falta', 'que', 'digas', 'tonterias', 'que', 'tos', 'sabemos']
# ['Qué', 'diferencia', 'con', 'el', 'Borbón', 'abrazafarolas', ',', 'eh', '!', '?']
# ['Pero', 'si', 'Will', 'es', 'el', 'genio', ',', 'abrazafarolas']
# ['Eres', 'un', 'abrazafarolas', '.']
# ['El', 'impoluto', ',', 'según', 'el', 'porcino', 'abrazafarolas', 'de', '🤣🐷🤣🐷🤣🐷🤣🐷🤣🐷🤣🐷🤣']
# ['No', 'te', 'me', 'pongas', 'asi', 'abrazafarolas']
# ['Madre', 'mía', 'la', 'cantidad', 'de', 'abrazafarolas', 'que', 'se', 'tragan', 'tus', 'bulos', '.']
# ['Gilipollas', ',', 'subnormal', ',', 'melón', ',', 'retrasado', ',', 'imbecil', ',', 'tonto', ',', 'malparido', ',', 'payaso', ',', 'chupacables', ',', 'retrasado', ',', 'hijo', 'de', 'puta', ',', 'cabronazo', ',', 'mierdaseca', ',', 'capullo', ',', 'y', 'porque', 'no', 'se', 'me', 'ocurren', 'mas', 'que', 'si', 'no', 'estaba', 'así', 'todo', 'el', 'dia', 'pedazo', 'mamón', '.']
# ['O', 'porque', 'eres', 'un', 'cuerpoescombro', ',', 'que', 'puede', 'ser', 'hasta', 'peor', '.']
# ['Soy', 'yo', 'o', 'el', 'rey', 'se', 'está', 'volviendo', 'un', 'cuerpoescombro', '?', 'Bienvenido', 'al', 'club', 'Su', 'Atleza', '.']
# ['Qué', 'dice', 'el', 'cuerpoescombro', 'este', '?']
# ['Panorámica', 'a', 'ojos', 'del', 'cuerpoescombro', '...', '.']
# ['virgen', 'jajaja', 'tanto', 'tiempo', 'llevas', 'aguantando', 'al', 'cuerpoescombro', 'este', '?']
# ['normativo', 'de', 'que', 'si', 'es', 'un', 'cuerpoescombro']
# ['Lameculos', 'profesional', '!', '!']
# ['Perdona', '?', 'Que', 'hablas', 'de', 'gente', 'mayor', ',', 'este', 'es', 'un', 'sinverguenza', 'macarra', 'y', 'lameculos']
# ['Rotundamente', 'SI', '...', 'lameculos']
# ['Susana', 'Griso', 'es', 'una', 'lameculos']
# ['Los', 'traidores-ras', 'en', 'este', 'país', 'brillan', 'por', 'su', 'presencia', ',', 'así', 'como', 'los', 'chivatos', 'y', 'falsos', 'lameculos', '.', 'Lo', 'llevan', 'escrito', 'en', 'su', 'puta', 'cara', '!']
# ['España', 'es', 'el', 'país', 'con', 'los', 'obreros', 'más', 'sumisos', 'y', 'lameculos', 'de', 'toda', 'Europa', '.', 'Cuanto', 'tenemos', 'que', 'aprender', 'de', 'los', 'franceses', ',', 'que', 'por', 'algo', 'tienen', 'unos', 'sueldos', 'bastante', 'más', 'dignos', 'que', 'nosotros', '...']
# ['Le', 'pides', 'demasiado', 'a', 'Ramoncete', 'morroestufa😂']
# ['Maricon', 'pagafantas', ',', 'tu', 'y', 'todos', 'los', 'líderes', 'políticos', 'deberíais', 'amanecer', 'ahorcados']
# ['Todo', 'es', 'culpa', 'de', 'los', 'pagafantas', 'que', 'creen', 'que', 'se', 'las', 'va', 'a', 'dar', 'a', 'oler']
# ['Sois', 'unos', 'pagafantas']
# ['No', ',', 'es', 'un', 'intelectual', ',', 'firme', 'en', 'sus', 'convicciones', ',', 'y', 'que', 'no', 'cede', 'en', 'su', 'defensa', ',', 'ante', 'las', 'necesidades', 'fisiológicas', 'de', 'la', 'entrepierna', '...', '¡Que', 'noooo', '!', '¡JAJAJAJA', '!', '¡Es', 'un', '“', 'pagafantas', '”', '!']
# ['Por', 'supuesto', '.', 'Pero', 'el', 'Real', 'Valladolid', ',', 'el', '“', 'pagafantas', '”', 'ideal', ',', 'debiera', 'averiguar', 'quien', 'ha', 'filtrado', 'esto', '.', 'Alguien', 'que', 'deba', 'justificar', 'su', 'gestión', 'y', 'el', 'asunto', 'se', 'le', 'estaba', 'empezando', 'a', 'hacer', '“', 'bola', '”', '.']
# ['¡Derechita', 'pagafantas', '!']
# ['Un', 'auténtico', 'pagafantas', '.']
# ['vaya', 'cara', 'de', 'tolai', 'tiene', 'el', 'Richard', 'este', '.']
# ['cada', 'dia', 'mas', 'subnormal', 'el', 'tolai', 'este']
# ['Son', 'muñecos', ',', 'tolai']
# ['Tú', 'el', 'rumbo', 'ya', 'lo', 'tienes', 'perdido', ',', 'tolai', '.', 'Antes', 'de', 'abandonar', 'el', 'partido', 'tenías', 'que', 'haber', 'hecho', 'esas', 'reflexiones', ',', 'igual', 'que', 'Íñigo', '.', 'Pero', 'el', 'uno', 'se', 'fue', 'por', 'la', 'puerta', 'de', 'atrás', 'y', 'el', 'otro', 'le', 'siguió', '.', 'Justo', 'cuando', 'más', 'unión', 'necesitaba', 'el', 'partido', '.', 'Llamazares', '.', 'desaparece', 'ya', ',', 'cenizo']
# ['Igual', 'quedo', 'd', 'tolai', ',', 'pero', 'q', 'le', 'pasa', 'a', 'la', 'chica', '?']
# ['Es', 'de', 'un', 'videoclip', 'en', 'el', 'que', 'le', 'hubieran', 'aplicado', 'censura', 'si', 'no', 'lo', 'hubiera', 'hecho', ',', 'tolai']
# ['No', 'mientas', 'que', 'estabas', 'en', 'la', 'graduación', 'tolai']
# ['Pues', 'a', 'mi', 'me', 'parece', 'un', 'tolai', ',', 'pero', 'vuelvo', 'a', 'decir', '...', 'q', 'cada', 'cual', 'se', 'ponga', 'lo', 'q', 'quiera', 'y', 'con', 'lo', 'q', 'se', 'sienta', 'bien', '.', 'Si', 'a', 'él', 'le', 'gusta', 'ponérsela', 'y', 'se', 've', 'guapo', ',', 'pues', 'palante', '😊']
# ['Una', 'duchita', 'al', 'perroflauta', 'no', 'le', 'habría', 'venido', 'mal', '.']
# ['Y', 'tanto', 'macho', ',', '14', 'horas', 'fuera', 'de', 'mi', 'casa', 'de', 'lunes', 'a', 'sábado', ',', 'así', 'pasa', 'que', 'luego', 'te', 'viene', 'un', 'perroflauta', 'a', 'decirte', 'que', 'tienes', 'que', 'currar', 'y', 'lo', 'mandas', 'bien', 'lejos']
# ['Hombre', ',', 'ya', 'salió', 'un', 'perroflauta', 'piojoso', '!']
# ['Viva', 'España', ',', 'y', 'Viva', 'los', 'Españoles', 'de', 'bien', '.', 'Como', 'diría', 'un', 'perroflauta..', 'Viva', 'España', ',', 'vivo', 'españo', ',', 'y', 'todas', 'y', 'todos']
# ['Quién', 'es', 'perroflauta', '?']
# ['lo', 'siento', 'hablo', 'en', 'castellano', 'no', 'en', 'perroflauta', 'no', 'podríamos', 'entendernos']
# ['Jajajaja', 'Hombre', '...', 'prefiero', 'un', 'casco', 'vikingo', 'antes', 'que', 'la', 'hoz', 'y', 'el', 'martllo', 'o', 'cualquier', 'símbolo', 'progre', 'comunista', 'perroflauta', '.']
# ['Cómo', 'cansa', 'la', 'gente', 'tan', 'parguela']
# ['La', 'que', 'le', 'ha', 'caído', 'al', 'mono', 'JAJAJAJAJAK', 'toda', 'la', 'comunidad', 'colgao', ',', 'para', 'el', 'suelo', 'parguela']
# ['Pero', 'si', 'me', 'estás', 'mirando', 'a', 'mí', ',', 'parguela']
# ['Vas', 'a', 'ir', 'a', 'la', 'cala', 'andando', ',', 'parguela']
# ['pero', 'que', 'dices', 'parguela', ',', 'duchate', 'cerdo']
# ['¿Qué', 'pasa', 'parguela', '?']
# ['Que', 'parguela', 'preguntando', 'estas', 'cosas', 'por', 'twitter']
# ['-', 'Tomate', ',', '¿para', 'qué', 'se', 'saca', 'la', 'bandera', 'de', 'mi', 'Españita', '?', '-', 'La', 'bandera', 'de', 'Españita', 'se', 'saca', 'para', 'conquistar', ',', 'el', 'que', 'la', 'saca', 'para', 'enseñarla', 'es', 'un', 'parguela', '.']
# ['Eres', 'un', 'cenutrio', '.']
# ['Hay', 'ser', 'muy', 'cenutrio', 'para', 'poner', 'ese', 'tuit', '...']
# ['Por', 'eso', ',', 'cenutrio']
# ['Islascanarias', 'Sería', 'la', 'zona', 'más', 'verde', ',', 'saludable', ',', 'impactante', 'y', 'turística', 'de', 'nuestra', 'Tierra', '.', 'Señoras', 'y', 'señores', 'políticos', 'de', 'm', '...', '..', '!', '¿', 'No', 'tenéis', 'hij', ',', 'niet', ',', 'sobrin', 'u', 'otra', 'equivalencia', 'genética', '?', 'No', 'hagáis', 'caso', 'al', 'cenútrio', 'ObreroDeDerechas', '...', '..']
# ['Esto', 'no', 'lo', 'olvidamos', ',', 'cenutrio', '.']
# ['Da', 'gusto', 'ver', 'tanto', 'cenutrio', 'juntos', '.']
# ['No', 'voy', 'a', 'perder', 'el', 'tiempo', 'con', 'un', 'cenutrio', 'como', 'tú', '.', 'No', 'das', 'el', 'nivel', '.']
# ['Fuera', ',', 'cenutrio', '.', 'A', 'vivir', 'toda', 'tu', 'vida', 'en', 'la', 'oscuridad', 'donde', 'naciste', '.']
# ['@', '_sarabel_', 'Fueron', 'los', 'del', 'a', 'por', 'ellos', ',', 'cenutrio', '.']
# ['Claro', '!', '!', 'Si', 'no', 'queremos', 'que', 'se', 'vaya', '!', '!', '!', 'Queremos', 'seguir', 'viendo', 'como', 'os', 'continúa', 'hundiendo', 'desde', 'su', 'piscina', 'de', 'Galapagar', '!', '!', 'Cenutrio', '!', '!', 'YoConPabloIglesias']
# ['Te', 'amo', 'mucho', 'más', 'amor']
# ['Ve', 'y', 'me', 'besas', 'despacito', 'mi', 'amor', '.']
# ['Amor', 'incondicional', 'en', 'estos', 'animalitos', ',', 'por', 'algo', 'y', 'es', 'el', 'mejor', 'amigo', 'del', 'hombre', '♥️', '.']
# ['El', 'amor', 'está', 'en', 'todas', 'partes', '.', '𝒥ℯ𝓁𝒾𝓏', '𝒽ℴ𝓎♥︎', '.']
# ['Usa', 'el', 'amor', 'como', 'un', 'puente']
# ['No', 'me', 'parece', 'tan', 'grave', ',', 'si', 'cortó', 'el', 'semáforo', 'y', 'hay', 'tránsito', '...']
# ['No', 'pidas', 'peras', 'al', 'semáforo', '.']
# ['El', 'momento', 'semáforo', 'se', 'ha', 'quedado', 'grabado', 'en', 'mi', 'corazón', '❤']
# ['Como', 'Peatón', 'también', 'tenemos', 'responsabilidades', ',', 'y', 'tenemos', 'que', 'asumirlas', '.', 'Esperar', 'el', 'semáforo', 'en', 'rojo', 'y', 'que', 'los', 'autos', 'se', 'hayan', 'detenido', 'por', 'completo', 'para', 'cruzar', 'una', 'calle', ',', 'utilizar', 'los', 'pasos', 'cebra', 'y', 'los', 'puentes', 'peatonales', 'en', 'avenidas', 'grandes', '.', 'Seamos', 'un', 'PeatónResponsable', '👍']
# ['Lo', 'único', 'que', 'he', 'podido', 'comprar', 'en', 'para', 'poder', 'sumarme', 'a', 'la', 'SemanaSinPlasticos', ':', 'un', 'melón', '|', 'amigos', 'de', 'las', 'grandes', 'cadenas', 'de', 'supermercados', ',', 'este', 'reto', 'lo', 'tenéis', 'que', 'liderar', 'vosotros', ',', 'si', 'no', ',', 'no', 'podemos', '😫']
# ['Un', 'video', 'comiendo', 'un', 'melon', 'c', ':']
# ['Si', 'digo', 'tú', ',', 'melón', 'jajajajaja']
# ['¿Cuál', 'es', 'la', 'fruta', 'más', 'deliciosa', '?', '—', 'Melón', '🤤🤤']
# ['28', 'melón']
# ['La', 'derechista', 'tocapelotas', '.']
# ['Se', 'muda', 'tu', 'vecina', 'tocapelotas', '?', '!', '!', 'Como', 'lo', 'vas', 'a', 'celebrar', '?', '?', '?', '🍸']
# ['Ellos', 'han', 'subido', '...', 'la', 'gente', 'esta', 'contenta', 'con', 'su', 'gestion', '...', 'y', 'no', 'me', 'da', 'la', 'gana', 'hablar', 'de', 'los', 'tocapelotas', 'que', 'tambien', 'han', 'subido', '.']
# ['@', '_edmac_', 'y', 'la', 'T', 'es', 'de', 'Tocapelotas', ',', 'como', 'uno', 'que', 'yo', 'me', 'sé']
# ['Es', 'un', 'sí', ',', 'joder', 'Kaila', 'es', 'que', 'eres', 'tocapelotas', 'hasta', 'para', 'eso', '.']
# ['-Desde', 'lo', 'de', 'Myra', 'ha', 'decidido', 'ignorar', 'a', 'los', 'fantasmas', 'tocapelotas-', '.']
# ['Este', 'tío', 'cada', 'más', 'tocapelotas', '...', 'el', 'señor', 'paradondeOblak', 'se', 'ha', 'creído', 'el', 'personaje', 'de', 'RRSS', 'q', 'difunde', 'y', 'cada', 'día', 'da', 'más', 'vergüenza', 'ajena', '.', 'Estoy', 'harto', 'de', 'leer', 'sus', 'bobadas', 'de', 'bobomerengue', '...', '.q', 'hastío', 'de', 'periolisto', '...', '😩']
# ['Un', 'capullo']
# ['ahora', 'me', 'envuelve', 'como', 'un', 'capullo', 'en', 'el', 'cual', 'no', 'deseo', 'salir', ',', 'estoy', 'tan', 'agradecida', 'con', 'seokjin', 'y', 'tan', 'enamorada', 'de', 'su', 'corazón', ',', 'el', 'mundo', 'y', 'yo', 'somos', 'tan', 'afortunados', 'de', 'tenerlo', 'THISNIGHTbyJIN', '이밤ByJinOutnow']
# ['capullo', ',', 'ella', 'canta', 'la', 'llorona']
# ['Que', 'me', 'dejes', 'capullo']
# ['Es', 'un', 'capullo']
# ['Qué', 'capullo', 'eres', '.', 'Ahora', 'yo', 'me', 'quedo', 'comiéndome', 'la', 'cabeza', 'y', 'tú', 'tan', 'ancho', '.']
# ['Hay', 'que', 'ser', 'capullo', 'para', 'escribir', 'eso', '.', 'Yo', 'no', 'veo', 'a', 'ningún', 'paleto', 'como', 'tú', 'muerto', 'en', 'ninguna', 'cuneta', '.', 'Eso', 'le', 'pertenece', 'a', 'eta', 'y', 'comunistas', '.']
# ['Pero', 'que', 'dices', 'zampabollos']
# ['¿Cabías', 'en', 'el', 'de', '50m2', 'zampabollos', '?']
# ['El', 'felón', 'de', 'la', 'sexta', '...', 'menudo', 'zampabollos', 'sectario', '...']
# ['te', 'pone', 'cachondo', 'o', 'algo', '?', 'zampabollos']
# ['Puto', 'niño', 'zampabollos']
# ['El', 'zampabollos', 'inepto', 'de', 'Zoido', 'está', 'en', 'el', 'euro', 'Parlamento', '?', '?', 'Acabará', 'con', 'todo', 'el', 'chucrut', 'de', 'Alsacia', '...', 'y', 'como', ',', 'según', 'él', 'declaró', 'en', 'el', 'juicio', ',', 'durante', '4', 'años', 'no', 'se', 'enterará', 'de', 'nada']
# ['Este', 'tweet', 'parece', 'sacado', 'de', 'un', 'mentecato', ',', 'seguirán', 'tragando', 'sus', 'palabras', '.']
# ['Tres', 'días', 'ya', '👍', 'Igual', 'es', 'muy', 'difícil', 'dar', 'con', 'el', 'de', 'la', 'reforma', '(', 'probablemente', 'ilegal', ')', 'y', 'meterle', 'un', 'puro', 'que', 'no', 'olvide', 'en', 'su', 'vida', ',', '¿o', 'acaso', 'el', 'mentecato', 'que', 'dirige', 'la', 'Policía', 'Municipal', 'también', 'hay', 'prohibido', 'esto', '?']
# ['Què', 'mentecato', 'es', 'este', 'Guaidog']
# ['te', 'llevo', 'en', 'la', 'mente', ',', 'mentecato']
# ['Saludos', 'mentecato', '.']
# ['Es', 'una', 'amenaza', 'debieras', 'denunciar', 'al', 'mentecato', 'que', 'te', 'escribió', 'eso']
# ['Santi', ',', 'eres', 'idiota', ',', 'desde', 'que', 'naciste', ',', 'y', 'eso', 'ya', 'no', 'lo', 'va', 'a', 'cambiar', 'nadie', '.', 'Cállate', 'e', 'intenta', 'no', 'liarla', 'más', ',', 'mentecato', '.']
# ['Si', 'Lérida', 'se', 'dice', 'Lleida', ',', '¿lerdo', 'se', 'dice', 'lleido', '?', 'Y', 'entonces', ',', 'leído', 'cómo', 'se', 'dice', '?', 'Lleído', '?', 'Joder', '!', 'No', 'entiendo', 'nada', '!', '😓']
# ['Eso', 'es', 'Lerdo', ',', 'no', 'c', 'mamen']
# ['Nada', ',', 'que', 'me', 'he', 'equivocado', 'y', 'soy', 'lerdo', 'jejejeje']
# ['No', 'os', 'cansais', 'de', 'hacer', 'el', 'lerdo', '?']
# ['Me', 'desperté', 'modo', 'GNC', 'hoy', ',', 'muy', 'lerdo', 'todo', '🙄']
# ['Un', 'olvido', 'repentino', 'burlando', 'a', 'un', 'tiempo', 'lerdo']
# ['Me', 'muero', ',', 'amorfo', 'jajajajaaj', '!', '!']
# ['decidme', 'q', 'vosotros', 'tb', 'lo', 'veis', 'amorfo']
# ['-Quiera', 'no', 'quiera', 'ha', 'salido', 'amorfo-']
# ['Esque', 'es', 'un', 'PAYASO', 'y', 'un', 'AMORFO', '.']
# ['Gilipuertas']
# ['Gilipuertas', 'everywhere', '.', 'Manda', 'webs', '!', '!', '!', '!', '!', '!', '!']
# ['Ah', ',', 'nadie', 'importante', ',', 'un', 'gilipuertas']
# ['Albano', '!', '...', 'que', 'cutre', 'y', 'gilipuertas', 'eres', 'macho', '!']
# ['Reciclad', 'estos', 'residuos', 'humanos', ',', 'es', 'salvar', 'tu', 'planeta', '.', 'Gracias', 'a', 'todos', ',', 'podemos', 'ayudar', 'a', 'dejar', 'nuestras', 'calles', 'libres', 'de', 'gilipuertas', '.', 'Por', 'un', 'mundo', 'mejor', ',', 'tu', 'mundo', '.', 'Ministerio', 'del', 'Interior', '.']
# ['Vete', 'a', 'cagar', 'gilipuertas', '...', '.']
# ['Y', 'para', 'qué', 'ibamos', 'a', 'votar', 'a', 'VOX', ',', 'para', 'regalarte', 'a', 'tí', 'los', 'votos', '?', '.', 'Hay', 'que', 'ser', 'gilipuertas', ',', 'y', 'politiquero', 'de', 'baja', 'estofa', '.', 'Nadie', 'sabe', 'más', 'de', 'poltronas', ',', 'que', 'vosotros', 'los', 'del', 'PP', ',', 'que', 'pagais', 'cualquier', 'precio', 'por', 'mantenerlas', '.']
# ['menudo', 'gilipuertas']
# ['jajajajaja', '...', 'vaya', 'gilipuertas']
# ['Estos', 'gilipuertas', 'aplauden', 'a', 'esta', 'familia', 'fascistas', 'de', 'actos', 'y', 'Súper', 'cool', 'de', 'boquilla', '!', 'Eres', ',', 'clínicas', 'privadas', 'y', 'exclusivas', '!', '!', 'Lo', 'que', 'es', 'hipocresía', 'en', 'botellón', 'con', 'Vega', 'Sicilia', '.']
# ['No', 'falla', 'uno', ',', 'analfabetos', 'funcionales', 'que', 'creen', 'que', 'el', 'resto', 'del', 'mundo', 'es', 'tan', 'gilipuertas', 'como', 'ellos', '!', '!', 'Otro', 'a', 'la', 'cola', 'del', 'Inaem']
# ['Pero', 'el', 'Valencia', 'que', 'tiene', 'que', 'ver', 'hay', ',', 'cazurro', '!', '!', '!']
# ['Y', 'porfi', ',', 'no', 'me', 'llames', 'cazurro', 'que', 'yo', 'a', 'ti', 'no', 'te', 'he', 'insultado']
# ['Jajajaja', 'aprende', 'a', 'escribir', 'puto', 'cazurro']
# ['Pon', 'comas', ',', 'cazurro', '.']
# ['Hay', 'que', 'ser', 'gilipollas', 'pa', 'ir', 'al', 'campo', 'cazurro', 'ese', '.']
# ['Cazurro', 'soy', 'yo', ',', 'ella', 'es', 'catalana', '.']
# ['José', 'Antonio', 'Reyes', 'ha', 'muerto', 'por', 'cazurro', '.', 'Es', 'de', 'ser', 'un', 'inconsciente', 'ir', 'a', 'esa', 'velocidad', '.']
# ['Al', 'igual', 'que', 'aznar', ',', 'cazurro', '!', '!', '!', '!']
# ['Tolosa', 'apaga', 'la', 'brasa', 'del', 'besugo']
# ['A', 'callar', 'besugo']
# ['Aprende', 'a', 'respetar', ',', 'besugo']
# ['Yo', 'me', 'he', 'callado', 'por', 'no', 'liarla', '.', 'Porque', 'me', 'conozco', ',', 'besugo', '.']
# ['Besugo', 'al', 'limón', ',', 'todo', 'un', 'festín', 'de', 'sabores']
# ['Besugo', 'tu', 'padre', '.']
# ['Florentino', 'sabe', 'k', 'ese', 'besugo', 'no', 'va', 'a', 'ir', 'a', 'ningun', 'pais', 'k', 'no', 'sea', 'españa']
# ['Fiesta', 'de', 'Besugo', 'y', 'de', 'la', 'Sidra', 'Imágenes', 'del', 'año', 'pasado', ',', 'buena', 'pinta', '¿verdad', '?', 'Erreserbak', '/', 'Reservas', '-', 'TolosaldeaTour', '943', '69', '74', '13', 'TxinpartaElkartea']
# ['Más', 'tonto', 'y', 'no', 'naces', 'besugo', '.']
# ['uf', 'q', 'pelma', 'eres', 'tía', 'q', 'si', 'no', 'lo', 'pillas', 'no', 'es', 'mi', 'problema']
# ['Inda', 'es', 'un', 'pelma']
# ['Eres', 'un', 'pelma']
# ['Además', 'tiene', 'su', 'cuenta', 'con', '11K', 'de', 'seguidores', 'y', 'es', 'una', 'pelma', 'de', 'cuidado', ',', 'menuda', 'tipeja', '.']
# ['Pasandoooo', ',', 'hay', 'gente', 'muy', 'pelma', '.', 'Animo', '!', '!', '!']
# ['Y', 'la', 'turra', 'que', 'ha', 'dado', 'con', 'Pedro', '...', 'que', 'tío', 'más', 'pelma', '.']
# ['Que', 'pelma', 'es', 'la', 'people', '.']
# ['Eres', 'pelma', 'de', 'cojones', ',', 'abuela', '.']
# ['Venga', 'pelma', ',', 'a', 'crear', 'el', 'ejercito', 'catalan']
# ['Venga', 'tio', ',', 'eres', 'un', 'pelma', ',', 'no', 'hacéis', 'más', 'que', 'dar', 'por', 'culo', '.']
# ['menudo', 'cabestro', 'este', 'Trump', '.']
# ['Este', 'viejo', 'cabestro', 'siempre', 'igual', ',', 'bético', 'Perro']
# ['jajajajajajaja', 'otra', 've', 'por', 'aqui', '?', 'un', 'abrazo', 'cabestro']
# ['Cuanto', 'cabestro', 'y', 'que', 'fácil', 'es', 'bloquear', 'en', 'Twitter']
# ['¿Un', 'cabestro', '?', ',', '¿un', 'cínico', '?', ',', '¿ambas', 'cosas', '?']
# ['A', 'pastar', '!', '!', 'Denegado', 'su', 'turno', 'de', 'palabra', ',', 'por', 'cabestro', '.']
# ['Valiente', 'cabestro', 'el', 'Sr.', 'Colegiado']
# ['La', 'narró', 'Pérez', 'Reverte', '.', 'Que', 'ni', 'leer', 'sabes', ',', 'mangurrián', '.']
# ['A', 'tolar', 'por', 'culo', 'mangurrián', '!', '!']
# ['Dos', 'fotos', 'juntas', 'se', 'entienden', 'mejor', ',', 'mangurrian', '.']
# ['¿Dignidad', 'de', 'qué', ',', 'mangurrián', ',', 'eres', 'más', 'digno', 'despreciando', 'a', 'tu', 'país', '?']
# ['Pero', 'qué', 'coño', 'vas', 'a', 'saber', 'tu', 'de', 'fútbol', 'si', 'solo', 'ves', 'el', 'color', 'blanco', ',', 'mangurrian', '.']
# ['Fuera', 'payaso', 'fuera']
# ['Payaso', 'ni', 'tu', 'te', 'la', 'crees']
# ['No', 'le', 'creen', 'al', 'payaso', 'del', 'actor', 'premier']
# ['Este', 'pobre', 'payaso', 'ya', 'no', 'sabe', 'donde', 'esta', 'el', 'norte', 'ni', 'el', 'sur', '.']
# ['alcalde', '?', 'este', 'es', 'un', 'payaso', '!']
# ['El', 'payaso', 'más', 'bien', '😂']
# ['Lo', 'gana', 'Murillo', ',', 'payaso']
# ['A', 'ese', 'payaso', 'cualquiera', 'le', 'gana😂😂😂😂']
# ['Sabía', 'yo', 'que', 'algún', 'día', 'la', 'letra', 'de', 'esta', 'canción', 'me', 'iba', 'a', 'venir', 'como', 'anillo', 'al', 'dedo', '...', 'Es', 'un', 'gran', 'necio', ',', 'un', 'estúpido', 'engreído', ',', 'egoísta', 'y', 'caprichoso', ',', 'un', 'payaso', 'vanidoso', ',', 'inconsciente', 'y', 'presumido', ',', 'falso', ',', 'enano', ',', 'rencoroso', '...']
# ['ENTRETÉNME', ',', 'PAYASO', '!', '!', '!', '...']
# ['—Se', 'lleva', 'una', 'mano', 'a', 'la', 'cara', '.', '¿De', 'verdad', 'podía', 'ser', 'tan', 'alcornoque', '?', '—', 'Bien', ',', 'más', 'para', 'ti', '.']
# ['Pedazo', 'de', 'alcornoque', ',', 'vindria', 'a', 'ser']
# ['Temas', 'del', 'Conocimiento', ':', 'Alcornoque', 'y', 'sus', 'Usos']
# ['Cabeza', 'de', 'alcornoque']
# ['Zopenco', ',', 'alcornoque', ',', 'soperutano', ',', 'soquete']
# ['Mockus', 'no', 'fue', 'auspiciador', 'de', 'la', 'guerrilla', ',', 'y', 'se', 'gano', 'contratos', 'de', 'forma', 'irregular', '.', 'Y', 'el', 'partido', 'verde', 'que', 'si', 'es', 'de', 'izquierda', 'tiene', 'bastantes', 'candidatos', 'cuestionados', 'incluyendo', 'a', 'la', 'gallito', '.', 'Lea', 'alcornoque', '.']
# ['Insistidor', 'este', 'cabeza', 'de', 'alcornoque', '.']
# ['Vaya', 'hombre', '.', 'Me', 'había', 'plantado', 'porque', 'creía', 'que', 'me', 'había', 'topado', 'con', 'un', 'alcornoque', '.']
# ['Cabeza', 'de', 'alcornoque', 'xd']
# ['el', 'cabeza', 'de', 'alcornoque', 'dice', 'que', 'tiene', 'otras', 'cifras', '.']
# ['Sectaria', 'dice', 'el', 'papanatas']
# ['España', 'una', 'democracia', 'de', 'complejos', 'y', 'papanatas', '.', 'El', 'día', 'que', 'reaccionemos', 'igual', 'será', 'tarde', '.']
# ['Es', 'casi', 'tan', 'papanatas', 'como', 'tú']
# ['Ah', 'que', 'mequetrefe']
# ['Jajajajajajajaja', 'mortal', '.', 'No', 'se', 'cansa', 'de', 'perder', 'este', 'mequetrefe', '!', '!', '!', '!']
# ['Te', 'perdono', ',', 'pero', 'no', 'soy', 'ladrón', 'y', 'tampoco', 'hay', 'ladrones', 'en', 'mi', 'familia', ',', 'asi', 'que', 'mas', 'respeto', ',', 'si', 'es', 'que', 'quieres', 'que', 'te', 'respete', ',', 'mequetrefe', '...', '!', '!']
# ['No', 'hay', 'nadie', 'que', 'le', 'de', 'su', 'merecido', 's', 'este', 'mequetrefe', '?', '?', '?', '?']
# ['Ese', 'soy', 'yo', 'que', 'te', 'pasa', 'pedazo', 'de', 'pelele']
# ['Es', 'un', 'vil', 'pelele', 'y', 'fantoche']
# ['Bueno', 'realmente', 'queda', 'como', 'pelele', ',', 'ogro', 'le', 'queda', 'grande', 'y', 'le', 'sobra']
# ['Tan', 'nazi', 'que', 'le', 'dijo', 'pelele', 'a', 'hitler']
# ['Quien', 'juzga', 'a', 'ese', 'pelele']
# ['Jamás', 'votaría', 'a', 'Vox', ',', 'pero', 'si', 'tengo', 'que', 'elegir', 'entre', 'Abascal', 'y', 'el', 'pelele', 'de', 'Vals', 'y', 'Macron', ',', 'sin', 'duda', 'me', 'quedo', 'con', 'los', 'primeros', '.', 'Es', 'que', 'no', 'se', 'puede', 'ser', 'más', 'hipócrita', 'y', 'engañabobos', 'que', 'Riveleta', '.']
# ['Porqué', 'no', 'señala', 'quienes', 'son', 'esos', 'constitucionalistas', 'de', 'prestigio', '?', 'Vamos', 'a', 'dejar', 'que', 'este', 'pelele', 'de', 'Gorriti', ',', 'se', 'quede', 'en', 'palacio', 'y', 'no', 'vaya', 'a', 'la', 'cárcel', 'por', 'corrupto', 'y', 'golpista', '?']
# ['Sigan', 'peleando', ',', 'la', 'gente', 'de', 'a', 'pie', 'esta', 'jodida', 'con', 'la', 'desaceleracion', 'economica', 'q', 'ya', 'no', 'alcanza', 'para', 'cubrir', 'gastos', 'minimos', ',', 'sigan', 'defendiendo', 'sus', 'intereses', ',', 'pelele', 'de', 'los', 'rojos']
# ['Qué', 'penita', 'da', 'Garzón', '...', '..un', 'pelele', 'en', 'manos', 'd', 'Iglesias', '...', '.no', 'me', 'extraña', 'q', 'Anguita', '...', '..en', 'fin', '...', 'y', 'lo', 'd', 'Rusia', '...', '.pues', 'mejorando', 'x', 'momentos', ',', 'todos', 'tienen', 'mugre', 'debajo', 'd', 'la', 'alfombra', ',', 'pero', 'estos', 'la', 'han', 'llenado', 'en', '4', 'días', '.']
# ['Vale', 'pichabrava']
# ['Puto', 'Amunike', 'menudo', 'pichabrava']
# ['Me', 'causan', 'el', 'mismo', 'rechazo', 'las', 'putas', 'y', 'los', 'pichabrava', 'esos', 'de', 'los', 'cojones', '.']
# ['Que', 'es', 'un', 'pichabrava', 'ya', 'lo', 'sabemos', 'todos', '.', 'Que', 'hay', 'mucha', 'oportunista', 'dispuesta', 'a', 'vivir', 'a', 'su', 'costa', ',', 'tambien', '.', 'Que', 'como', 'no', 'cambie', 'su', 'modo', 'de', 'vida', 'a', 'los', '28', 'años', 'va', 'a', 'estar', 'acabado', 'como', 'futbolista', ',', 'seguro', '.']
# ['Juan', 'Carlos', 'I', 'El', 'Pichabrava']
# ['Pues', 'un', 'pichabrava', 'que', 'no', 'se', 'pilla', ',', 'que', 'hay', 'que', 'decírtelo', 'todo', '.']
# ['Trump', 'el', 'PichaBrava', 'ejerció', 'su', 'derecho', 'a', 'la', 'libertad', 'en', 'el', 'culo', 'de', 'la', 'princesa', 'de', 'HUAWEI', '.', 'La', 'princesa', ',', 'emborrachada', 'y', 'drogada', 'primero', ',', 'y', 'preñada', 'a', 'la', 'fuerza', '(', 'al', 'principio', ')', ',', 'después', ',', 'dijo', 'ser', 'sabedora', 'del', 'carácter', 'diabólico', 'del', 'engendro', ',', 'y', 'q', 'la', 'suda', 'el', 'coño', '...', 'lo', 'va', 'ha', 'tener', '.']
# ['Por', 'eso', 'lo', 'pongo', 'de', 'castigo', ',', 'cabezabuque']
# ['Rastrajoso', ',', 'revientacabezas', ',', 'muerdepiedras', ',', 'cabezabuque', 'xD']
# ['¡Cómo', 'estará', 'de', 'negra', 'la', 'conciencia', 'de', 'Cabezabuque', 'para', 'emitir', 'tanto', 'comunicado', '...', '!']
# ['Me', 'parece', 'un', 'insulto', 'decir', 'que', 'Raúl', 'Bravo', 'es', 'el', 'cabecilla', 'de', 'cualquier', 'trama', '.', 'En', 'todo', 'caso', 'es', 'el', 'cabezabuque', 'más', 'grande', 'que', 'se', 'conoce', '.', 'LaFábrica']
# ['Estimado', 'botarate', ',', 'esa', 'adjudicación', 'la', 'efectuó', 'el', 'PP', '.', 'Saludos', 'cordiales', '!', '!']
# ['Cállese', 'burro', ',', 'lea', 'libros', 'y', 'tuitee', 'menos', ',', 'botarate', '.']
# ['Cinco', 'añitos', '?', 'Los', 'niños', 'tienen', 'más', 'sentido', 'común', 'que', 'este', 'botarate', '...']
# ['1', ')', 'No', 'votar', 'a', 'PP', 'y', 'a', 'Vox', 'no', 'supone', 'que', 'no', 'se', 'pueda', 'comentar', 'nada', 'del', 'PP', 'y', 'de', 'Vox', '.', '2', ')', 'No', 'votar', 'a', 'Podemos', ',', 'ni', 'al', 'dúo', 'de', 'Galapagar', ',', 'no', 'significa', 'que', 'no', 'se', 'pueda', 'comentar', 'su', 'pésima', 'estrategia', '.', '3', ')', 'Lo', 'más', 'importante', ':', 'comento', 'lo', 'que', 'me', 'sale', 'de', 'los', 'golondrinos', 'en', 'mi', 'TL', ',', 'botarate', '.']
# ['Botarate', 'del', 'Copon']
# ['No', 'me', 'extraña', 'que', 'con', 'gentuza', 'como', 'tú', 'esté', 'país', 'sea', 'cada', 'día', 'más', 'una', 'mierda', 'botarate']
# ['Al', 'loro', ',', 'que', 'la', 'línea', 'editorial', 'de', 'este', 'botarate', 'ha', 'movido', 'a', 'mucho', 'carrilbicista', 'madrileño', 'en', 'los', 'últimos', 'cuatro', 'años', 'de', 'gobierno', 'de', 'Es', 'gente', 'con', 'traumas', 'a', 'los', 'que', 'le', 'dan', 'el', 'poder', 'de', 'planificar', 'y', 'decidir', 'sobre', 'todos', 'los', 'demás', '.']
# ['No', 'tengo', 'ninguna', 'duda', '.', 'Es', 'un', 'botarate', '.']
# ['No', 'es', 'más', 'botarate', 'porque', 'no', 'se', 'entrena', '.', 'Cualidades', 'de', 'partida', 'le', 'sobran', '.', '¿De', 'dónde', 'salen', 'estos', 'figuras', '?']
# ['Ya', 'sabía', 'que', 'eras', 'picapleitos', '.', '😉']
# ['Eres', 'un', 'jodido', 'picapleitos', 'y', 'ya', 'cansas', 'con', 'tus', 'malas', ',', 'malísimas', 'entrevistas', '.', 'Paladín', 'de', 'la', 'democracia', 'y', 'de', 'la', 'libertad', 'de', 'expresión', '.', 'Destruyes', 'la', 'verdad', '.']
# ['Mi', 'tuit', 'fijao', ',', 'marica', 'picapleitos']
# ['Tu', 'eres', 'abogado', '?', 'Si', 'lo', 'fueras', 'tendrias', 'que', 'haber', 'leìdo', 'la', 'consttuciòn', '.', 'Sòlo', 'que', 'eres', 'un', 'picapleitos', 'CORRUPTO', '!', '!', '!', '!', '!']
# ['Rey', 'de', 'la', 'provincia', 'de', 'Vigo', 'desde', '2007', ',', 'experto', 'picapleitos', 'con', 'la', ',', 'hacedor', 'de', 'turbo', 'rotondas', 'y', 'plantador', 'de', 'olivos', 'milenarios', '💯😍😘🤣']
# ['Este', 'picapleitos', 'vendido', 'a', 'los', 'separatas', 'nazi', 'catalán']
# ['El', 'juicio', 'del', 'prucés', 'encontró', 'en', 'Pablo', 'Ordaz', 'a', 'un', 'genial', 'cronista', ',', 'que', 'de', 'forma', 'magistral', 'inicia', 'hoy', 'su', 'texto', '.', 'Smith', 'y', 'Fernánandez', ',', 'así', 'podrían', 'llamar', 'a', 'ese', 'par', 'de', 'picapleitos', 'bostezantes', '.']
# ['El', 'tipico', 'lumbreras', 'de', 'Potemos']
# ['La', 'nueva', 'viñeta', 'de', 'Orlando', 'Lumbreras', ':', "'Logos", "'", 'opinión', 'viñeta']
# ['Según', 'este', 'lumbreras', ',', 'se', 'los', 'debieron', 'enviar', 'los', 'americanos', '.']
# ['Gracias', 'por', 'la', 'info', 'LUMBRERAS', '.']
# ['Pero', 'el', 'lumbreras', 'de', 'no', 'lo', 'sabe.😎']
# ['Al', 'lumbreras', 'que', 'se', 'le', 'ocurrió', 'poner', 'garbanzos', 'a', 'los', 'frutos', 'secos', 'al', 'gulag', 'y', 'ni', 'agua', '.']
# ['Mi', 'hija', 'tiene', '10', 'de', 'media', '.', 'Y', 'calcula', 'que', 'ha', 'sacado', 'un', '6.3', 'Ella', 'quería', 'hacer', 'grado', 'de', 'Mates', 'hace', 'tiempo', '.', 'Ahora', 'Ingeniería', 'Informática', '.', 'Al', 'menos', 'en', 'esta', 'l', 'nota', 'de', 'corte', 'es', 'baja', '.', 'Felicidades', 'a', 'los', 'lumbreras', 'que', 'pusieron', 'el', 'examen', '.', 'El', 'día', 'q', 'den', 'las', 'notas', 'veremos', 'qué', 'pasa', '.', 'PAU2019']
# ['Pues', 'si', 'hubiesen', 'castrado', 'a', 'tu', 'padre', 'tú', 'no', 'hubieses', 'nacido', 'lumbreras']
# ['Dos', 'nuevas', 'familias', 'han', 'encontrado', 'su', 'hogar', 'con', 'nosotros', '.', '¿Quieres', 'ser', 'la', 'siguiente', '?', '.', 'Trabajamos', 'en', 'Puerto', 'Lumbreras', ',', 'Lorca', ',', 'Totana', ',', 'Caravaca', 'de', 'la', 'Cruz', ',', 'Calasparra', ',', 'Mula', 'y', 'Cehegín', '.', '!', 'Dinos', 'lo', 'que', 'buscas', 'y', 'te', 'ayudaremos', 'a', 'encontrarlo', '!', '🗝️🏠👏🏼👥', '•', 'inmobiliaria', 'morillas', 'hogar']
# ['14h', 'PUERTO', 'LUMBRERAS', ':', 'Temp', '.', '25.9', '°C', ',', 'Hum', '.', '31', '%', ',', 'Bar', '.', '1008.6', 'hPa', ',', 'Lluvia', '0.0', 'mm', ',', 'Viento', '15.8', 'km/h', 'SSE', 'Weathercloud']
# ['Lo', 'ha', 'sido', ',', 'por', 'eso', 'Setién', 'está', 'despedido', '.', 'Lumbreras']
# ['Donald', 'Trump', 'patán', 'o', 'macarra', 'barriobajero', '?']
# ['Rata', 'mora', 'fue', 'pésimo', 'y', 'barriobajero', ',', 'que', 'tío', 'más', 'asqueroso', ',', 'fuera', 'de', 'Sálvame', 'ya', '!', '!', '!']
# ['Ruben', 'Cruz', 'acabará', 'mal', '.', 'Es', 'un', 'barriobajero']
# ['Me', 'recuerda', 'a', 'las', 'ostias', 'q', 'repartia', 'el', 'barriobajero', 'madrid', 'de', 'mou', 'en', 'los', 'cladicos', ',', 'a', 'mamar']
# ['Vaya', 'codazo', 'barriobajero']
# ['Juego', 'sucio', 'no', ',', 'barriobajero', '.']
# ['Espero', 'que', 'pida', 'perdón', 'por', 'esta', 'acción', 'de', 'barriobajero', 'paleto', '.']
# ['Lo', 'del', 'Cartagena', 'es', 'de', 'matones', 'y', 'muy', 'barriobajero', '.', 'Rubén', 'Cruz', 'y', 'Cordero', 'van', 'a', 'terminar', 'el', 'partido', 'sin', 'ver', 'la', 'roja', '...', '.', 'Han', 'sido', 'mejores', 'pero', 'las', 'maneras', 'no', ',', 'y', 'el', 'árbitro', 'demasiado', 'permisivo', '.', 'PlayOff']
# ['Antonio', 'Montero', ',', 'en', 'tu', 'descripción', 'te', 'falta', 'tarado', 'emocional', 'barriobajero', 'y', 'mentecato']
# ['Ahora', 'en', 'el', 'blog', '❯', '12', 'recetas', 'de', 'tartar', 'de', 'atún', 'para', 'disfrutar', 'de', 'platos', 'frescos', 'y', 'nutritivos', 'en', 'verano', 'vía']
# ['Acabo', 'de', 'abrir', 'una', 'lata', 'de', 'atún', 'con', 'un', 'cuchillo', '.', 'Ya', 'me', 'gradué', 'de', 'adulto', 'independiente', '.']
# ['A', 'alguien', 'más', 'les', 'gusta', 'el', 'huevo', 'con', 'atún', '?']
# ['Domingo', 'de', 'ver', 'series', 'y', 'comer', 'atún', '...', 'a', 'veces', 'duele', 'la', 'dieta', '.']
# ['Receta', 'de', 'tortilla', 'de', 'atún', 'y', 'tomate', '🍰', 'REGÁLANOS', 'UN', 'RETWEET', '🍧', 'postres', 'dulces', 'recetas', '&', 'gt', ';']
# ['Tendrá', 'atún', ',', '¿no', '?', 'Qué', 'menos', '...']
# ['Macarrones', 'al', 'atún', 'gratinados', 'en', 'el', 'Circus', ',', 'paseo', 'por', 'el', 'palmeral', 'y', 'dos', 'horas', 'de', 'siesta', '.', 'No', 'queráis', 'venderme', 'otro', 'plan', 'de', 'domingo', 'PORQUE', 'NO', 'LO', 'COMPRO', '.']
# ['La', 'crema', 'Nivea', 'fría', 'en', 'el', 'cuerpo', ',', 'los', 'sándwiches', 'de', 'atún', 'enlatado', ',', 'las', 'empanadas', 'de', 'cazón', 'en', 'la', 'Santiago', 'Mariño', ',', 'Parque', 'El', 'Agua', ',', 'el', 'atardecer', 'en', 'Juan', 'Griego', '...', 'Muchos', 'recuerdos', 'bonitos', '.']
# ['Salimos', 'de', 'Otero', 'de', 'Guardo', ',', 'un', 'pequeño', 'pueblo', 'de', 'la', 'Montaña', 'Palentina', '.']
# ['Fin', 'de', 'semana', 'en', 'Bilbao', ',', '¡y', 'sin', 'pisar', 'el', 'Guggenheim', '!', 'El', 'binomio', 'mar', 'y', 'montaña', 'que', 'rodea', 'a', 'la', 'capital', 'de', 'Vizcaya', 'es', 'insuperable', 'Euskadi']
# ['Felicidades', 'Enhorabuena', 'Lou', 'lou', 'grande', 'Maillot', 'de', 'la', 'montaña', 'y', 'clasificación']
# ['Ascensión', 'al', 'pico', 'Boum', ',', 'valle', 'de', 'Remuñé', 'Benasque', 'Un', 'nuevo', 'éxito', 'del', 'actividad', 'de', 'Alta', 'Montaña', '.']
# ['Si', 'te', 'gustan', 'las', 'actividades', 'en', 'la', 'montaña', ',', 'no', 'te', 'pierdas', 'nuestro', 'artículo', 'en', 'el', 'que', 'te', 'decimos', 'cuales', 'son', 'las', 'mejores', 'chaquetas', 'para', 'montaña', 'con', 'la', 'mejor', 'relación', 'calidad-precio', '-', 'deportes', 'senderismo', 'montañismo', 'trekking']
# ['De', 'despertar', 'en', 'la', 'cima', 'de', 'una', 'montaña', 'para', '2minutos', 'despues', 'dejarme', 'caer', 'al', 'fondo', 'del', 'oceao', '.', 'Asi', 'va', 'dia', 'y', 'el', 'tuyo', ',']
# ['🔵', 'Lo', 'que', 'nunca', 'debes', 'hacer', 'cuando', 'conduces', 'un', 'coche', 'con', 'caja', 'de', 'cambios', 'manual', 'Motor']
# ['Coche', 'no', 'sé', ',', 'pero', 'hay', 'bus', 'cada', 'media', 'hora', 'desde', 'Plaza', 'Elíptica', '(', 'y', 'se', 'puede', 'usar', 'el', 'bono', 'transporte', 'de', 'madrid', ')']
# ['Money', 'Talks', '|', 'Tesla', 'se', 'tira', 'a', 'la', 'piscina', 'con', 'un', 'coche', 'submarino']
# ['Un', 'micrófono', 'en', 'el', 'coche', 'de', 'Aranda', 'probaría', 'el', 'presunto', 'acuerdo', 'para', 'el', 'resultado', 'entre', 'el', 'Valladolid', 'vs', 'Valencia']
# ['Mañana', 'vuelvo', 'en', 'coche', 'y', 'solo', 'voy', 'a', 'hacer', 'un', 'examen', 'jj']
# ['Necesito', 'un', 'coche', 'y', 'el', 'carné', 'de', 'conducir..']
# ['Soñé', 'que', 'me', 'robaban', 'el', 'coche', '😓']
# ['Ayer', 'aguanté', 'como', 'una', 'campeona', 'sin', 'beber', 'nada', 'd', 'alcohol', 'porq', 'iba', 'con', 'el', 'coche', ',', 'ahora', 'puedo', 'con', 'todo', 'lo', 'q', 'se', 'me', 'ponga', 'por', 'dlante']
# ['En', 'el', 'coche', 'del', 'tío', 'para', 'la', 'tierra', 'a', 'trabajar']
# ['Una', 'hora', 'y', '35', 'minutos', 'esperando', 'un', 'autobús', ',', 'como', 'te', 'echo', 'de', 'menos', 'coche', '😭']
# ['¡Echa', 'un', 'vistazo', 'a', 'mi', 'transmisión', 'desde', 'mi', 'PlayStation', '4', '!', 'PS4live', '(', 'Gran', 'Turismo™SPORT', ')', 'live', 'at']
# ['Buena', 'transmisión']
# ['Y', 'la', 'transmisión', '?']
# ['nos', 'dañaron', 'el', 'domingo', 'a', 'los', 'q', 'íbamos', 'a', 'ver', 'la', 'transmisión', 'por', 'YouTube', '😪']
# ['ROBERTO', 'GONZÁLEZ', 'Candidato', 'a', 'la', 'Muni', 'Capitalina', 'por', 'CREO', 'llega', 'a', 'votar', 'a', 'Z11', '.', 'Transmisión', 'de', 'Radio', 'Sonora', '.', '.', 'El', 'deseo', 'por', 'servir', 'se', 'mantiene', 'y', 'para', 'una', 'nueva', 'era', 'en', 'la', 'Municipalidad', '.']
# ['¡Echa', 'un', 'vistazo', 'a', 'mi', 'transmisión', 'de', '(', 'Fortnite', ')', 'live', 'at']
# ['Las', '10', 'infecciones', 'de', 'transmisión', 'sexual', 'más', 'frecuentes', 'Salud']
# ['Le', 'ruego', 'que', 'no', 'me', 'tutee', '.', 'Respecto', 'al', 'como', 'siempre', ',', 'no', 'sé', 'dónde', 'hizo', 'Ud', 'la', 'Selectividad', ',', 'pero', 'en', 'algunas', 'CCAA', 'ponen', 'textos', 'no', 'argumentativos', '.', 'Literarios', ',', 'por', 'ejemplo', '.', 'Y', 'no', 'siempre', 'se', 'pide', 'la', 'opinión', '.', 'Ah', ',', 'y', 'mis', 'opiniones', 'tendrán', '*sesgo*', ',', 'pero', 'yo', 'no', 'pongo', 'las', 'pruebas', 'de', 'la', 'EBAU', '.']
# ['Entregarán', '178.000', 'firmas', 'por', 'una', 'Selectividad', 'única', 'en', 'toda', 'España']
# ['Una', 'niña', 'que', 'acaba', 'de', 'hacer', 'selectividad', 'me', 'ha', 'preguntado', 'sobre', 'Farmacia', ',', 'chicos', 'que', 'le', 'digo', '?']
# ['La', 'selectividad', 'ha', 'dejado', 'la', 'nota', 'media', 'más', 'baja', 'de', 'los', 'últimos', 'años', '.', 'Desde', '2013', 'los', 'estudiantes', 'no', 'promediaban', 'una', 'puntuación', 'menor', '.', 'En', 'concreto', 'ha', 'sido', 'de', 'un', '6,27', ',', 'lo', 'que', 'supone', '29', 'décimas', 'peor', 'que', 'el', 'año', 'pasado', '.']
# ['Selectividad', 'del', '2020', '.', 'Historia', 'del', 'arte', '.', 'Describa', 'este', 'cuadro', '.']
# ['Esa', 'habitación', 'debería', 'salir', 'en', 'los', 'exámenes', 'de', 'historia', 'de', 'selectividad']
# ['Los', 'alumnos', 'con', 'dislexia', 'podrán', 'tener', 'faltas', 'de', 'ortografía', 'en', 'la', 'Selectividad', 'vía']
# ['Pero', 'seguro', 'que', 'no', 'aprobaría', 'la', 'selectividad', 'de', 'Madrid']
# ['q', 'nota', 'has', 'sacado', 'en', 'selectividad', '—', '10,27', 'jajajaj']
# ['Sí', ',', 'soy', 'a', 'andaluza', 'viviendo', 'en', 'Madrid', '.', 'Hice', 'la', 'selectividad', 'en', 'Andalucía', '.']
# ['Yo', 'rodeada', 'de', 'mis', 'apuntes', 'de', 'selectividad', 'para', 'quemarlos']
# ['Empiezan', 'mis', 'vacaciones']
# ['Esta', 'de', 'vacaciones', '...', 'como', 'siempre']
# ['Vacaciones', '.', 'Casa', '.', 'Gatillos.Surete', '.', 'Netflix', '.', 'Soy', 'feliz😊', 'faltas', 'tú']
# ['Me', 'encanta', 'planear', 'las', 'vacaciones', 'con', '...']
# ['Sii', 'falta', 'poquito', ',', 'me', 'los', 'llevo', 'en', 'verano', ',', 'ahora', 'son', 'muy', 'cortitas', 'las', 'vacaciones', 'AJJAJA']
# ['—', 'Buenas', 'tardes', '.', 'Que', 'días', 'más', 'ajetreados', 'enseñando', 'a', 'los', 'animales', 'nuevos', 'espectáculos', ',', 'necesita', 'vacaciones', '.']
# ['Termina', 'este', 'miércoles', 'y', 'acabo', 'de', 'terminar', 'mis', 'vacaciones', 'xD']
# ['Esperando', 'que', 'mi', 'papi', 'me', 'lleve', 'd', 'vacaciones', 'ahí']
# ['Tengo', 'familia', 'en', 'Berlin', ',', 'mis', 'primos', 'se', 'vienen', 'el', '20', 'de', 'vacaciones', 'para', 'La', 'Coruña', ',', 'Galicia', ',', 'Spain']
# ['Ya', 'quiero', 'salirrr', ',', 'necesito', 'vacaciones', 'jeje']
# ['sólo', '3', 'semanas', 'para', 'vacaciones', '😭😭😭😭']
# ['Las', 'vacaciones', '*']
# ['Se', 'fue', 'de', 'vacaciones', 'x', 'el', 'estrés', '.']
# ['Me', 'urgen', 'unas', 'vacaciones', '.', 'Eternas', '.']
# ['Las', 'vacaciones', 'son', 'un', 'derecho', 'que', 'tiene', 'todo', 'trabajador', 'para', 'gozar', 'de', 'un', 'descanso', 'de', '15', 'días', 'hábiles', 'por', 'cada', 'año', 'de', 'trabajo', '.', 'Ingresa', 'a', 'LegalApp', 'y', 'conoce', 'qué', 'hacer', 'en', 'este', 'caso', '.', 'YoUsoLegalApp', '&', 'gt', ';']
# ['¡Ya', 'huele', 'a', 'vacaciones', 'y', 'nuestro', 'estilo', 'lo', 'sabe', '!', '😎🌴LookSemanal', 'RAGGED']
# ['vamos', 'a', 'la', 'playa', 'oooo']
# ['-Nada', ',', 'día', 'de', 'playa-']
# ['Escuché', 'una', 'canción', 'durante', 'una', 'hora', 'en', 'el', 'camino', 'de', 'ida', 'a', 'la', 'playa', '.', '¿cuál', 'canción', 'crees', 'que', 'era', '?']
# ['Espero', 'que', 'entrenes', 'en', 'la', 'playa', '😉']
# ['Si', 'hay', 'sol', 'hay', 'playa', ',', 'si', 'hay', 'playa', 'hay', 'alcohol', '...', 'si', 'hay', 'alcohol', 'hay', 'sexo', 'y', 'si', 'es', 'contigo', 'mejor🎵']
# ['Necesito', 'playa', ':', '(']
# ['Mazarrón', 'Retiran', '200', 'kilos', 'de', 'basura', 'marina', 'en', 'la', 'playa', 'de', 'Bolnuevo']
# ['📲', ':', 'Supuse', 'que', 'sabía', '...', 'Pero', 'la', 'playa', 'no', 'me', 'suena', '.', '📲', ':', 'Si', ',', 'si', '...', 'Te', 'veo', 'en', 'la', 'playa', ',', 'entonces']
# ['Toda', 'la', 'gente', 'de', 'Alcasser', 'se', 'daba', 'ostias', 'hablando', 'mal', 'para', 'estar', 'en', 'el', 'programa', '.', 'Yo', 'no', 'sé', 'ni', 'qué', 'decir', '...', 'los', 'familiares', 'en', 'ese', 'estado', 'de', 'shock', 'no', 'se', 'darían', 'cuenta', 'de', 'lo', 'que', 'estaban', 'haciendo', ',', 'pero', 'con', 'el', 'tiempo', 'debieron', 'abrir', 'los', 'ojos', 'y', 'sentir', 'aún', 'más', 'impotencia', 'del', 'poco', 'respeto']
# ['Moderación', '?', 'Jaajajajjaja', '.', 'Libertad', '?', 'Para', 'quién', '?', 'Progreso', '?', '?', '?', '?', 'Estamos', 'hablando', 'de', 'la', 'misma', 'persona', 'y', 'del', 'mismo', 'programa', '?']
# ['¿Tu', 'seguirás', 'con', 'tu', 'programa', 'o', 'ya', 'hay', 'cambios', 'de', 'todo', 'inmediatos', '?']
# ['Porqué', 'insisten', 'en', 'el', 'programa', 'de', 'Vecinos', 'vigilantes', 'si', 'las', 'denuncias', 'no', 'las', 'atienden', ',', 'los', 'mismos', 'sitios', 'siguen', 'vendiendo', 'sus', 'drogas']
# ['El', 'programa', 'pretende', 'controlar', 'el', 'daño', 'que', 'generan', 'en', 'la', 'fauna', 'silvestre', 'y', 'a', 'la', 'agricultura', 'campesina']
# ['🔵', 'Terraformación', ',', 'el', 'programa', 'de', 'la', 'NASA', 'para', 'cambiar', 'el', 'clima', 'de', 'Marte', 'y', 'hacerlo', 'habitable', 'MedioAmbiente']
# ['Aquí', 'os', 'dejamos', 'nuestro', 'nuevo', 'programa', 'con', 'la', 'gran', 'ayuda', 'de', 'nuestro', 'amigo', 'del', 'gran', 'podcast', 'entre', 'otros', 'muchos', '.', 'Muchas', 'gracias', '.', 'podcast', 'Cine', 'Stargate', 'claqueta', 'y', 'accion', '2x16', 'stargate']
# ['Si', 'no', 'generas', 'el', 'escenario', 'Comuns-PSC', ',', 'no', 'hay', 'Valls', 'que', 'valga', '.', 'Comuns', 'tiene', 'con', 'ERC', 'un', 'programa', 'mucho', 'más', 'parecido', 'que', 'con', 'el', 'PSC', 'pero', 'escogió', 'PSC', 'para', 'asegurarse', 'a', 'Valls', '.', 'Y', 'en', 'política', ',', 'nada', 'es', 'a', 'cambio', 'de', 'nada', '.', 'NADA', '.']
# ['Donde', 'están', 'los', 'amigos', 'que', 'tienen', 'piscina', '😫😫']
# ['Quisiera', 'estar', 'en', 'una', 'piscina', ',', 'rai', 'nau']
# ['¡Yo', 'estoy', 'muy', 'bien', '!', '¡Con', 'ganas', 'de', 'piscina', 'o', 'playa', '!']
# ['Pedro', 'solo', 'baja', 'a', 'la', 'piscina', 'por', 'las', 'tardes', ',', 'porque', 'la', 'socorrista', 'del', 'segundo', 'turno', 'es', 'una', 'chica', '.']
# ['Lo', 'mejor', 'de', 'la', 'noche', 'fue', 'meterme', 'en', 'la', 'piscina', ',', 'que', 'risa', 'jajajaja', 'menuda', 'panorama']
# ['Estoy', 'en', 'la', 'piscina', '.']
# ['Asi', 'da', 'gusto', 'venir', 'a', 'la', 'piscina', ',', 'una', 'pasada', 'todo', ',', 'muchas', 'gracias', '🤤😍']
# ['Ha', 'venido', 'uno', 'a', 'la', 'piscina', 'con', 'la', 'NINTENDO', 'DS']
# ['no', 'me', 'vaciles', 'que', 'te', 'echo', 'de', 'la', 'piscina', 'eh', 'jajajajaj']
# ['Yo', 'opte', 'por', 'la', 'piscina', ',', 'siempre', 'fui', 'más', 'de', 'agua', '!', '😀']
# ['Yo', 'me', 'tiro', 'a', 'la', 'piscina', 'XD']
# ['Alguien', 'me', 'invita', 'a', 'su', 'piscina', 'para', 'tomar', 'el', 'sol', 'estas', 'dos', 'semanas', 'que', 'vienen', '?', '🙄🙄']
# ['La', 'ONU', 'da', 'un', 'premio', 'al', 'Ayuntamiento', 'de', 'Madrid', 'de', 'Manuela', 'Carmena']
# ['El', 'nuevo', 'Ayuntamiento', 'de', 'Madrid', 'dejará', 'de', 'luchar', 'contra', 'el', 'cambio', 'climático']
# ['José', 'López', 'se', 'dirige', 'a', 'la', 'multitud', 'concentrada', 'frente', 'al', 'Ayuntamiento', 'de', 'Cartagena', 'en', 'protesta', 'por', 'el', 'pacto']
# ['En', 'la', 'web', 'del', 'ayuntamiento', '.']
# ['Pues', 'igual', 'que', 'Maragall', 'que', 'ya', 'tiene', 'su', 'puesto', 'y', 'su', 'sueldo', 'de', 'Edil', 'en', 'el', 'Ayuntamiento', 'de', 'Barcelona', '.']
# ['Ayer', 'tomamos', 'posesión', 'los', 'concejales', 'de', 'la', 'XI', 'legislatura', 'del', 'Ayuntamiento', 'de', 'Argés', '.', 'Es', 'el', 'pistoletazo', 'de', 'salida', 'para', 'trabajar', 'muy', 'duro', 'estos', 'años', 'por', 'los', 'argeseñ', '.', 'Vamos', 'a', 'realizar', 'una', 'oposición', 'crítica', 'y', 'constructiva', '.', 'Prometemos', 'luchar', 'por', 'un', 'Argés', 'de', 'futuro', 'y', '+social', '.']
# ['Saluden', 'a', 'Andrea', 'Levy', ',', 'nueva', 'Concejala', 'de', 'Cultura', 'del', 'Ayuntamiento', 'de', 'Madrid', '.', 'FelizDomingo']
# ['Andrea', 'Levy', ',', 'concejala', 'de', 'Cultura', 'del', 'Ayuntamiento', 'de', 'Madrid', '.', 'No', 'doy', '.', 'laconcejalaantropófaga', 'pp', 'Madrid']
# ['Problemas', 'realísimos', ',', 'como', 'poner', 'la', 'ikurriña', 'en', 'el', 'balcón', 'del', 'Ayuntamiento']
# ['Ya', 'hay', 'alcaldes', 'esperando', 'en', 'la', 'puerta', 'del', 'ayuntamiento']
# ['Le', 'han', 'impuesto', 'el', 'euskera', 'astro', 'que', 'han', 'echado', 'de', 'la', 'escuela', 'infantil', 'por', 'no', 'querer', 'modelo', 'de', 'euskera', '.', 'Le', 'han', 'impuesto', 'la', 'ikurriña', 'en', 'el', 'ayuntamiento', ',', 'que', 'también', 'es', 'su', 'casa', ',', 'la', 'de', 'todos', '.']
# ['Si', 'hombre', '!', 'A', 'la', 'gente', 'humilde', 'le', 'irá', 'genial', 'la', 'para', 'de', 'C', "'s", 'en', 'el', 'Ayuntamiento', ',', 'ya', 'veréis', '!']
# ['Eso', 'es', 'cosa', 'del', 'Ayuntamiento', '.', 'La', 'ciudad', 'por', 'suerte', 'no', 'es', 'de', 'la', 'Iglesia']
# ['Un', 'documental', 'para', 'contar', 'cómo', 'ha', 'acabado', 'el', 'Ayuntamiento', 'de', 'Valencia', 'con', 'el', 'colapso', 'del', 'colector', 'norte', 'por', 'culpa', 'de', 'las', 'toallitas', 'húmedas', 'Lo', 'cuenta']
# ['El', 'Ayuntamiento', 'de', 'Madrid', 'pone', 'a', 'disposición', 'de', 'todos', 'los', 'carteles', 'que', 'han', 'adornado', 'la', 'ciudad', 'desde', '2016', 'diseñográfico']
# ['Y', 'muchos', 'profesionales', 'sin', 'trabajo..', '😪']
# ['Despidos', ',', 'trabajo', 'en', 'negro', ',', 'accidentes', ',', 'etc', '.', 'Consulte', 'expertos', '!']
# ['Es', 'posible', 'que', 'haya', 'otras', 'formas', 'respetables', 'de', 'ver', 'la', 'vida', 'y', 'el', 'trabajo', ',', 'en', 'función', 'de', 'las', 'circunstancias', 'de', 'cada', 'uno', '.', 'Piénsalo', '.', 'En', 'mi', 'opinión', 'te', 'están', 'quedando', 'pelín', 'clasistas', 'algunas', 'opiniones', 'al', 'respecto', 'de', 'la', 'encuesta', 'del', 'Farmacéutico', '.', 'Sin', 'acritud', '.']
# ['Un', 'día', 'más', 'de', 'trabajo', 'es', 'un', 'día', 'más', 'cerca', 'a', 'mi', 'jubilación', '.']
# ['Buen', 'domingo', '🎼😊👍', 'ya', 'verás', 'que', 'tú', 'cerebro', 'hará', 'el', 'trabajo', ':', ')']
# ['🔵', '5', 'aspectos', 'muy', 'curiosos', '(', 'e', 'incluso', 'peligrosos', ')', 'de', 'la', 'cultura', 'laboral', 'en', 'Japón', 'Trabajo']
# ['Ofertas', 'Trabajo', 'Content', 'Autocoding', 'Specialist', '-', 'Barcelona', 'en', 'Barcelona']
# ['Ofertas', 'Trabajo', 'Comercial', 'Rrhh', '-', 'Barcelona', 'en', 'Barcelona']
# ['Ofertas', 'Trabajo', 'Enfermero/A', 'Y/O', 'Fisioterapeuta', 'Para', 'Domicilios', 'En', 'Álava', '-', 'Talent', 'Search', 'People', 'en', 'Otra']
# ...
# ['Es', 'que', 'lo', 'de', 'Hervias..', 'y', 'eso', 'que', 'dicen', 'que', 'es', 'el', 'cerebro', 'de', 'Cs', '.']
# ['Efectivamente', 'Elecciones', 'Andaluzas/', '584.040', 'votos', 'Elecciones', 'Generales', 'Andalucía/', ':', '651.160', 'votos']
# ['Hoy', 'tocó', 'ruta', 'de', 'senderismo', '.', 'Asturias', 'Tazones', 'DonBosco', 'ProyectoNatura', 'leonesp']
# ['Finde', 'de', '⛰🌳', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'NonFilters', 'SierraDeMaría', 'LosVélez', 'Andalucía', 'Senderismo', 'Hiking', 'Friends', 'Traveling', 'en', 'Parque', 'Natural', 'de', 'María', 'Los', 'Vélez']
# ['benditas', 'excursiones', 'de', 'biología', 'ft', 'senderismo']
# ['Senderismo', 'Universidad', 'Popular', 'de', 'Albacete', '.', 'Hasta', 'el', 'curso', 'que', 'viene', '.', 'Felices', 'vacaciones', '!']
# ['Imágenes', 'de', 'la', 'Ruta', 'del', 'día', '15/06/19', ',', 'de', 'Senderismo', 'por', 'la', 'SierraDeGuara', 'Huesca', 'CanariasClimb', 'YoSoyDeCanariasClimb', 'en', 'Sierra', 'de', 'Guara']
# ['7', 'Rutas', 'de', 'senderismo', 'en', 'Castellón', 'provincia']
# ['YOGA', '&', 'amp', ';', 'SENDERISMO', 'EN', 'PICOS', 'DE', 'EUROPA']
# ['Tan', 'efímera', 'la', 'vida', ',', 'tan', 'corta', 'Hoy', 'iré', 'a', 'El', 'Ávila', 'Un', 'poquito', 'de', 'senderismo', 'no', 'hace', 'nada', 'mal', '.', 'Los', 'hierbajos', 'de', 'hace', 'poco', 'han', 'renacido', 'y', 'se', 'les', 'nota', 'el', 'verde', 'en', 'las', 'muy', 'pequeñas', 'hojas', ';', 'el', 'agua', 'del', 'riachuelo', 'corre', 'con', 'mas', 'fuerza', ';', 'los', 'pájaros', 'andan', 'porái', '(', 'vienen', 'a', 'mi', 'casa', 'a', 'cada', 'rato', ')']
# ['¿Preparad', '@', 'para', 'la', 'marcha', 'senderista', 'Nocturna', 'Bandolera', '?', '🌌', '🚶\u200d♀️🚶\u200d♂️', '🏁', 'El', 'próximo', '5', 'de', 'julio', 'salida', 'desde', 'Gambrinus', 'a', 'las', '22:00', 'horas', 'con', 'un', 'recorrido', 'de', '14kms', '.', 'Más', 'info', ':', 'Amontíllate', 'Montilla', 'deporte', 'Senderismo']
# ['Soñé', 'que', 'aprobaba', 'los', '100', 'Mt', 'en', 'natación', '..', 'Por', 'favor', 'que', 'así', 'sea', '😭']
# ['Natación', 'Dos', 'australianos', 'vencen', 'al', 'Estrecho', 'de', 'Gibraltar']
# ['Cuando', 'tu', 'colé', 'no', 'tiene', 'piscina', 'y', 'tienes', 'que', 'hacer', 'natación', 'sincronizada', '...']
# ['Gracias', 'por', 'vuestra', 'visita', ',', 'volved', 'pronto', '!', 'Y', 'buen', 'viaje', 'amigos', '.', 'Enhorabuena', 'Natación', 'TrofeoRCNDelfin']
# ['La', 'natación', ',', 'un', 'estilo', 'de', 'vida']
# ['Gracias', 'Carmena', 'por', 'cargarte', 'los', 'Clubs', 'de', 'natación', 'de', 'Madrid']
# ['Me', 'sentaría', 'enseñar', 'natación', 'en', 'colegios', 'que', 'cubren', 'necesidades', 'especiales']
# ['Natación', 'en', 'piscina', 'olímpica', '.', '👌👏🏊\u200d♂️']
# ['Nuestro', 'equipo', 'de', 'sincronizada', 'en', 'el', 'Campeonato', 'de', 'Madrid', '.', 'Natación', 'sincro', 'VillaviciosadeOdón']
# ['Muchas', 'felicidades', 'al', 'son', 'Campeones', 'de', 'España', 'de', 'Natación', 'Adaptada', '🏊\u200d♀️🏊\u200d♂️', 'Mataró', 'maresme', 'catalunya', 'natacion', '@', '_FEDPC_']
# ['No', 'hay', 'tiempo', 'para', 'estar', 'triste']
# ['Jugamos', 'con', 'uno', 'menos', 'el', 'primer', 'tiempo']
# ['Porque', 'todos', 'tus', 'tweets', 'son', 'tan', 'tristes', '?', ':', '(']
# ['¿Qué', 'tan', 'similares', 'son', 'nuestros', 'gustos', '?', '10', '%', 'cuartos', 'oscuros', '.', '10', '%', 'orgías', '.', '10', '%', 'drogas', '.', '(', 'abundan', 'poppers', ',', 'tachas', ',', 'alcohol', 'y', 'cocaína', ')', '10', '%', 'vapores/saunas', '.', '10', '%', 'bareback', '(', 'sexo', 'sin', 'protección', ')', '10', '%', 'sexo', 'en', 'baños', 'públicos', '.', '10', '%', 'apps', 'de', 'ligue', '.', '🏳️\u200d🌈']
# ['increíble', 'como', 'logras', 'tener', 'mi', 'atención', 'tan', 'fácil']
# ['Acomode', 'tan', 'mal', 'mis', '4', 'almohadas', 'anoche', 'que', 'hoy', 'me', 'desperté', 'con', 'alto', 'dolor', 'de', 'espalda']
# ['Nunk', 'dormi', 'tan', 'mal', 'como', 'anoche']
# ['Nunca', 'me', 'había', 'sentido', 'tan', 'sola', 'como', 'hoy']
# ['por', 'el', 'amor', 'de', 'dios', 'necesito', 'ese', 'anillo', 'de', 'Pandora', ',', 'no', 'puede', 'ser', 'tan', 'tan', 'hermoso']
# ['Que', 'nos', 'perdone', 'nuestra', 'nación', 'por', 'tener', 'un', 'gobierno', 'tan', 'ignorante', '.']
# ['Day', '9', ':', 'Grandísimo', 'Imbécil']
# ['Aplausos', ',', 'señor', 'Abreu', '.', 'Como', 'el', 'grandísimo', 'Gustavo', 'Bueno', ',', 'pero', 'más', 'expeditivo', '.']
# ['El', 'guionista', 'de', 'ese', 'capítulo', 'se', 'merecia', 'todos', 'los', 'premios', 'posibles', '.', 'Grandisimo', '!', '(', 'Y', 'muy', 'triste', ')']
# ['El', 'Barça', 'no', 'va', 'a', 'transferir', 'a', 'Dembélé', 'y', 'bien', 'hecho', 'porque', 'es', 'un', 'grandísimo', 'jugador']
# ['Casemiro', 'sobre', 'James', ':', 'Sería', 'muy', 'importante', 'para', 'nosotros', 'que', 'regrese', 'al', 'Real', 'Madrid', '.', 'Ya', 'demostró', 'a', 'todo', 'el', 'mundo', 'que', 'es', 'un', 'gran', 'jugador', '.', 'Tengo', 'un', 'cariño', 'grandísimo', 'por', 'él', ',', 'como', 'jugador', 'y', 'como', 'persona', '.', 'Seguro', 'si', 'regresa', 'al', 'Real', 'Madrid', 'será', 'bienvenido', 'por', 'todas', 'sus', 'cualidades', '.']
# ['Es', 'un', 'grandísimo', 'hijo', 'de', 'puta', '.', 'La', 'vida', 'te', 'cobrará', 'todo', 'esto', ',', 'malnacido', 'de', 'mierda']
# ['Grandísimo', 'fichaje', '.']
# ['Es', 'un', 'bicho', 'si', ',', 'pero', '29', 'años', 'o', 'casi', '.', 'Mucha', 'pasta', '.', 'Pero', 'grandisimo', 'central']
# ['Este', 'de', 'los', 'tirantes', 'no', 'vale', 'ni', 'para', 'payaso..Con', 'admiracion', 'para', 'los', 'grandes', 'payasos.Este', 'es', 'un', 'grandisimo', 'chufla', '.']
# ['hazle', 'un', 'favor', 'al', 'BARÇA', 'y', 'vete', 'a', 'la', 'mierda', ',', 'grandísimo', 'hijoputa', '.', 'Eres', 'el', 'cáncer', 'del', 'BARÇA', '.']
# ['Felicidades', '.', 'A', 'sido', 'un', 'grandísimo', 'torneo', 'si', 'señor']
# ['pedrerol', 'no', 'se', 'puede', 'ser', 'mas', 'HIPÓCRITA']
# ['No', 'se', 'puede', 'ser', 'mas', 'inhumana', ',', 'ud', ',', 'ha', 'leido', 'el', 'informe', 'de', 'la', 'ONU', ',', 'amnistia', 'inter.amnistia', 'es', ',', 'pen', 'etc.Porque', 'no', 'habla', 'de', 'los', 'privilegips', 'del', 'cuñado', 'del', 'rey', '?']
# ['Mejor', 'yo', 'diría', 'que', 'no', 'se', 'puede', 'ser', 'más', 'apátrida', 'quitando', 'la', 'luz', 'todos', 'los', 'días', 'a', 'toda', 'hora']
# ['No', 'se', 'puede', 'ser', 'más', 'bueno', 'que', 'Adri']
# ['No', 'se', 'puede', 'ser', 'más', 'inútil', 'que', 'yo']
# ['No', 'se', 'puede', 'ser', 'más', 'imbecil', '.']
# ['No', 'se', 'puede', 'ser', 'mas', 'mierda', 'ok']
# ['No', 'sé', 'puede', 'ser', 'más', 'desagradable']
# ['Jugando', 'draven', 'y', 'vayne', 'no', 'se', 'puede', 'ser', 'más', 'guarro']
# ['No', 'se', 'puede', 'ser', 'más', 'inútil', 'que', 'esta', 'directiva', ',', 'se', 'hace', 'TT', 'ValverdeOUT', 'y', 'publican', 'que', 'la', 'mayoría', 'fuimos', 'bots', 'franceses', ',', 'de', 'verdad', 'creían', 'que', 'iban', 'a', 'acallar', 'las', 'críticas', 'con', 'eso', '?', 'Pues', 'aquí', 'otro', 'que', 'utilizó', 'ese', 'hashtag', 'sin', 'ser', 'un', 'bot', 'francés', ',', 'id', 'buscando', 'otra', 'excusa', '.', 'BotDeCensura']
# ['Respeta', 'al', 'Rey', 'y', 'lárgate', 'a', 'tu', 'casa', 'como', 'dijiste', ',', 'ya', 'han', 'pasado', '18', 'meses', 'y', 'podras', 'dedicar', 'tu', 'tiempo', 'a', 'hacer', 'muchos', 'lacitos', 'amarillos', '.', 'No', 'se', 'puede', 'ser', 'más', 'ignorante', '.']
# ['tú', 'eres', 'un', 'puerco', ',', 'te', 'falta', 'el', 'corral']
# ['Es', 'que', 'eres', 'un', 'pivón', 'de', 'amiga', ',', 'así', 'te', 'lo', 'digo']
# ['ERES', 'UN', 'SOLLLL']
# ['eres', 'un', 'sinvergüenza']
# [';', 'Eres', 'un', 'ángel']
# ['te', 'reto', 'a', 'un', 'pvp', 'con', 'mi', 'mando', 'dañado', 'por', 'que', 'no', 'funciona', 'el', 'L2', 'y', 'lo', 'configure', 'y', 'ahora', 'apunto', 'con', 'L1', 'y', 'es', 'dificil', 'pero', 'quiero', 'ver', 'si', 'me', 'ganas', 'estoy', 'como', 'luis_solano-1998', 'es', 'de', 'epic', 'y', 'si', 'me', 'ganas', 'hago', 'un', 'video', 'dicendote', 'que', 'te', 'amo', 'y', 'que', 'eres', 'un', 'crack', 'jajaj']
# ['En', 'serio', 'eres', 'un', 'amor']
# ['Es', 'que', 'eres', 'un', 'puto', 'genio']
# ['Callate', ',', 'eres', 'un', 'bot']
# ['Ya', 'eres', 'un', 'anciano']
# ['Si', 'pactas', 'con', 'etarras', '...', 'eres', 'un', 'hijo', 'de', 'puta', '.', 'Así', 'de', 'claro', '.']
# ['La', 'histérica', ',', 'la', 'loca', 'y', 'la', 'feminazi', ':', 'las', 'nuevas', 'etiquetas', 'para', 'la', 'mujer', 'intelectualmente', 'inquieta', '.']
# ['La', 'feminazi', 'del', 'dia', '...', 'En', 'serio', ',', 'se', 'nos', 'va', 'de', 'las', 'manos', '...']
# ['Respuesta', 'a', 'un', 'intelectual', 'sobre', 'por', 'qué', 'utilizo', 'el', 'término', 'Feminazi']
# ['feminazi', 'no', 'se', ',', 'pero', 'gilipollas', 'te', 'aseguro', 'que', 'si']
# ['Se', 'me', 'hace', 'medio', 'feminazi', 'el', 'comentario', 'y', 'aun', 'así', 'lo', 'encuentro', 'tan', 'atinado']
# ['Jajaja', 'se', 'encabronó', 'la', 'porcina', 'feminazi', '😂😂😂😂']
# ['Con', 'esa', 'última', 'frase', ',', 'se', 'recibió', 'me', 'persona', 'de', 'mierda', '.', 'Al', 'lado', 'de', 'Hitler', '.', 'La', 'real', 'feminazi', '.']
# ['Feminista', 'es', 'diferente', 'a', 'feminazi', '.', 'Tengan', 'eso', 'bien', 'clarito', '!']
# ['Feminazi', 'en', 'búsqueda', 'desesperada', 'de', 'atención', '.', '¿todo', 'bien', 'en', 'casa', '?', '.']
# ['perdón', 'x', 'no', 'ser', 'una', 'feminazi~', 'u.u']
# ['Hipócrita', ',', 'feminazi', ',', 'demagoga', '.']
# ['Ser', 'un', 'buen', 'catolico', 'o', 'creyente', 'no', 'es', 'escandalizarse', 'o', 'juzgar', 'como', 'actuan', 'los', 'demas', ',', 'si', 'tanto', 'te', 'molesta', 'ignorarla', ',', 'no', 'necesariamente', 'puede', 'ser', 'una', 'feminazi', 'puede', 'ser', 'atea', 'y', 'tus', 'principios', 'no', 'son', 'los', 'mismos', 'que', 'ella', '...', '..', 'y', 'si', 'simplemente', 'ignoras', 'la', 'sibtuacion', 'o', 'la', 'sobrepasas']
# ['Bigdata', 'y', 'algoritmos', 'para', 'predecir', 'enfermedades', 'o', 'exacerbaciones', '.', 'Vía', 'prnoticias', 'esalud']
# ['Errores', 'que', 'se', 'pueden', 'cometer', 'al', 'crear', 'campañas', 'con', 'Big', 'Data']
# ['El', 'Big', 'Data', 'ha', 'llegado', 'para', 'quedarse', 'en', 'el', 'fútbol', 'español', '(', 'Real', 'Betis', 'y', 'Levante', 'UD', ')', 'vía']
# ['La', 'sub21', 'tiene', 'menos', 'tiro', 'que', 'el', 'big', 'data']
# ['Eres', 'el', 'Big', 'Data', '?', 'Realmente', 'vivimos', 'en', 'una', 'simulación', '...']
# ['Ya', 'mismo', 'sacan', 'una', 'serie', 'nueva', 'en', 'Netflix', '...', 'THE', 'BIG', 'DATA', 'THEORY', '...']
# ['Se', 'llama', 'big', 'data', 'no', 'es', 'brujería']
# ['Esperemos', 'que', 'el', 'Big', 'Data', 'de', 'el', 'visto', 'bueno', 'para', 'el', 'pago', 'de', 'la', 'cláusula']
# ['¿Sabés', 'lo', 'que', 'es', 'BigData', '?', '.', 'Este', 'servicio', 'también', 'te', 'lo', 'ofrecemos', 'en', 'Gutbit']
# ['Se', 'le', 'llama', 'big', 'data', '.']
# ['Data', 'Science', 'aplicada', '.']
# ['De', 'nada', ',', 'sigo', 'con', 'interés', 'el', 'mundo', 'del', 'Data', 'Science', '.']
# ['En', 'Fcen', 'no', 'está', 'Estadística', 'Matemática', '?', 'después', 'está', 'el', 'de', 'data', 'science', 'en', 'computación', 'pero', 'ya', 'nos', 'vamos', 'a', 'otro', 'lado', '.']
# ['14', '.', 'Silvia', 'Ferreira', ',', 'líder', 'de', 'Data', 'Science', 'en']
# ['El', 'Madrid', 'Internet', 'Of', 'Things', 'Institute', 'Es', 'el', 'primer', 'centro', 'de', 'formación', 'postgrado', '100', '%', 'IoT', 'de', 'España', '.', 'En', 'este', 'instituto', 'impartirán', 'Máster', 'en', 'IoT', ',', 'Data', 'Science', ',', 'y', 'un', 'programa', 'más', 'empresarial', ';', 'el', 'IoT', 'Executive', '.', 'Estamos', 'deseando', 'ver', 'cómo', 'evoluciona', 'este', 'centro', '.']
# ['Todas', 'las', 'preguntas', 'frecuentes', 'del', 'Máster', 'Interuniversitario', 'en', 'Ciencia', 'de', 'Datos', '/', 'Master', 'in', 'Data', 'Science']
# ['Ánimo', 'y', 'suerte', '.', 'No', 'es', 'fácil', 'el', 'Data', 'Science', '(', 'no', 'me', 'acostumbro', 'a', 'la', 'forma', 'en', 'español', ')', '.']
# ['¿Qué', 'es', 'big', 'data', '?', '¿Qué', 'es', 'data', 'science', '?', '¿En', 'qué', 'difieren', '?', '👉', 'TransformaciónDigital', '.']
# ['El', 'Data', 'Science']
# ['Nuevo', 'Evento', ':', 'Mini', 'taller', ':', 'Python', 'para', 'data', 'science', '20/06/2019']
# ['Regresión', 'Logística', ',', 'Data', 'Science']
# ['Charla', 'TED', 'sobre', 'el', 'uso', 'de', 'Data', 'Science', 'y', 'la', 'Inteligencia', 'Artificial', '.', 'DataScience', 'Tecnología', 'Tecnología', 'Ver', 'más', ':']
# ['Día', 'Mundial', 'de', 'las', 'Personas', 'Refugiadas', ':', 'conoce', 'a', 'los', 'voluntarios', 'de', 'la', 'UOC', 'vía']
# ['Has', 'mirado', 'la', 'UOC', '?', 'Es', 'a', 'distancia', 'pero', 'más', 'amena', ',', 'con', 'evaluación', 'más', 'continua', 'y', 'eso']
# ['Arranca', 'en', 'Xàbia', 'la', 'Escuela', 'de', 'Verano', ':', 'Fake', 'news', 'y', 'posverdad', 'de', 'la', 'Cátedra', 'de', 'Transparencia', 'UPV', 'El', 'lema', 'de', 'la', 'edición', 'es', '“', 'Deconstruyedo', 'la', 'realidad', '.', 'Impacto', 'de', 'las', 'fakenews', 'y', 'la', 'posverdad', '”', 'y', 'ha', 'sido', 'coorganizada', 'junto', 'a', 'la', 'UOC', ',', 'y', 'el', '.']
# ['Ole', '!', 'Yo', 'los', 'acabé', 'el', 'sábado', '(', '3', ')', '.', '(', 'También', 'soy', 'víctima', 'de', 'la', 'UOC', ')']
# ['Los', 'pilares', 'clave', 'para', 'impulsar', 'tu', 'carrera', 'profesional', 'son', 'trabajar', 'una', 'buena', 'marca', 'personal', 'y', 'desarrollar', 'una', 'efectiva', 'estrategia', 'de', 'networking', '.', 'Ayer', 'abordé', 'estos', 'dos', 'temas', 'en', 'el', 'marco', 'del', "'Encuentro", 'UOC', 'Alumni', "'", 'en', 'el', 'Impact', 'Hub', 'Vigo', '.', 'Fueron', 'unas', 'horas', 'm…']
# ['Ahora', 'que', 'termino', 'UOC', 'hará', 'septiembre', ',', 'quiero', 'trastear', 'con', 'Unreal', 'para', 'hacer', 'un', 'juego', 'en', '2D', '.', 'Recomendaciones', '?', 'Más', 'que', 'tutoriales', 'de', 'Unreal', ',', 'de', 'cómo', 'diseñar', 'el', 'juego', ',', 'tamaños', 'de', 'los', 'tiles', 'y', 'sprites', 'recomendados', 'para', 'PC', ',', 'trucos', 'a', 'tener', 'en', 'cuenta', ',', 'etc', '¿', '?']
# ['Ser', 'jefa/e', 'de', 'UOC', 'implica', 'gran', 'responsabilidad', ',', 'ahora', 'la', 'jefatura', 'de', 'Capacitacion', 'no', 'tiene', 'los', 'mismos', 'beneficios', 'da', 'a', 'entender', ',', 'pero', 'el', 'fondo', 'es', 'la', 'forma', 'en', 'que', 'la', 'denigraron', 'y', 'juzgaron', 'por', 'unas', 'fotos', '.']
# ['Nlp', 'francis', 'jajaaja']
# ['Victor', 'Kuppers', ',', '45', 'minutos', 'geniales', 'de', 'motivación', '/', 'NLP', 'via']
# ['Esos', 'términos', 'me', 'suenan', 'de', 'NLP', 'pero', 'tendría', 'que', 'investigar', 'bien', '.', 'Si', 'me', 'tiras', 'una', 'punta', 'le', 'meto', 'a', 'pleno']
# ['Otro', 'reto', ':', 'incorporar', 'AI', ',', 'NLP', ',', '...']
# ['A', 'mi', 'y', 'a', 'Karla', 'nlp']
# ['wow', 'Enhorabuena', 'Eduardo', '!']
# ['al', 'parecer', 'la', 'prepa', 'nlp', '...']
# ['Empuje', 'chino', 'para', 'ganar', 'la', 'AI', 'wef19', 'ArtificialIntelligence', 'MachineLearning', 'DeepLearning', 'NLP', 'carrera', 'NLG', 'ComputerVision', 'armamentística', 'Robotics']
# ['Este', 'finde', 'tocó', 'darle', 'al', 'NLP', 'y', 'APIcloudSpeech', 'de', 'Google', 'via', 'Rstats', '.', 'Y', 'no', 'sé', 'por', 'qué', 'acabe', 'analizando', 'la', 'presentación', 'de', 'en', '2009', '.', 'Dejando', 'a', 'un', 'lado', 'el', 'tema', 'técnico', 'os', 'dejo', 'esta', 'perla', 'de', 'video', 'donde', 'deja', 'claro', 'el', 'tema', 'IMPUESTOS', 'y', 'que', 'le', 'pasó', 'factura', '10', 'años', 'después']
# ['Emoción', 'de', 'lingüista', ':', 'dícese', 'cuando', 'asistes', 'a', 'una', 'masterclass', 'de', 'la', 'gran', ',', 'filóloga', 'y', 'manager', 'general', 'de', ',', 'explica', 'qué', 'es', 'la', 'IA', 'y', 'la', 'relevancia', 'de', 'la', 'lingüística', 'aplicada', 'en', 'este', 'campo', 'y', 'sus', 'usos', 'en', 'diferentes', 'mercados', '.', 'WeLoveLinguistics', 'NLP', 'TechTalks']

# %% [markdown]
# ** Cuenta del número de emoticonos . **

# %%
import emoji
def extract_emojis(str):
  return ' '.join(c for c in str if c in emoji.UNICODE_EMOJI)

# %%
df['emojis']=df['texto'].apply(lambda txt: extract_emojis(txt))

# %%
df['num_emoji']=df[df.emojis != '']['emojis'].apply(lambda txt: int(len(txt.split(' '))))
df.num_emoji=df.num_emoji.fillna(0)
df.num_emoji=df.num_emoji.astype(int)
df.num_emoji.iloc[1]
# Out:
# 0

# %%
aux=df[df.num_emoji != 0]['emojis'].tolist()
#set(aux)

# %% [markdown]
# **Label del número de palabras identificadas como tóxicas en en corpus **

# %%
import re
from unicodedata import normalize
# necesitamos quitar los acentos y las diéresis para no sustituir palabras como moño a mono (no podemos utilizar la libreia unicode)
#Pasamos todo el texto a minúsculas
#Quitamos acentos y diéresis 
def estandarización(string):
    res=string.lower()
    res=re.sub(r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", normalize( "NFD", res), 0, re.I)
    res=normalize( 'NFC', res)
    return res

# %%
### Librería de insultos
# Obtenida de https://listas.20minutos.es/lista/insultos-en-castellano-que-deberias-conocer-y-su-significado-393340/
path_lib_insultos="C:/Users/Esperanza/Desktop/UOC/TFM/python/libreria_insultos.txt"

# %%
# Lectura de la anterior librería
with open(path_lib_insultos, encoding='utf8') as f:
    lista_insultos = f.read().splitlines()

# Supresión de mayúsculas y acentos debido a que en las redes sociales es muy común no utilizarlos. 
estand_lib_ins = []
for i in lista_insultos:
    estand_lib_ins.append(estandarización(i))

# %%
#Obtenemos un label con la cantidad de veces que aparece una palabra considerada como tóxica. 
def num_insultos(texto): 
    return len([word for word in texto.split() if word in estand_lib_ins])

# %%
df['num_insultos']=df['texto'].apply(lambda txt: num_insultos(estandarización(txt)))

# %%
df[df.num_insultos == 2]
# Out:
#                                                  texto  toxico  num_admir  \
# 2    Tú eres tan cabrón que los estás jodiendo Que ...       1          0
# 111  Hay que ser capullo para escribir eso. Yo no v...       1          0
# 213                        Es un vil pelele y fantoche       1          0
#
#      num_may emojis  num_emoji  num_insultos
# 2          0                 0             2
# 111        0                 0             2
# 213        0                 0             2

# %% [markdown]
# **A quién va dirigido **

# %%
# Definición de la función que identificará si las frase es no incluyente
lista=['eres',"es", 'son', 'sois']# Uno de los atrones comunes cuando se insulta es utilizar el verbo ser no incluyente

def otra_persona(texto):
    res=0
    for elem in lista: 
        if(texto.find(elem) != -1 ): res=1
    return res

# %%
#Creación de la columna que comprueba la no unclisuión de la primera persona
df["dir_23ps"]=df.texto.map(lambda txt:otra_persona(txt) )

# %%
#Comprobación
set(df["dir_23ps"].tolist())
# Out:
# {0, 1}

# %% [markdown]
# ** Nivel de toxicidad a través de los emoticonos**

# %%
path_lib_emoji="C:/Users/Esperanza/Desktop/UOC/TFM/python/Libraries_Emojis.csv"
df_train = pd.read_csv(path_lib_emoji, sep=';')
df_train_aux=df_train[['EMOJIS', 'Neg']]
diccionario_neg=df_train_aux.set_index('EMOJIS').T.to_dict('dict')
#list(diccionario_neg.keys())
diccionario_neg.get('🌌')['Neg']
# Out:
# 0.12

# %%
def score_total_toxic(text):
    suma=[]
    try:
        suma=[diccionario_neg.get(value)['Neg'] for value in text.split() ]
        res=sum(float(i) for i in suma)/len(suma)
    except: 
        res=0
    return res

# %%
#Creación de la columna de nivel de toxicidad
df["score_emoji_tox"]=df.emojis[df.emojis !=''].map(lambda x: score_total_toxic(x))
df["score_emoji_tox"]=df.score_emoji_tox.fillna(0)

# %%
#set(df[df["score_emoji_tox"]].tolist())
#score_total_toxic('🌌 🌌 🌌')
#diccionario_neg.get('🌌')['Neg']
#data=['0.12', '0.12', '0.12']
#sum(float(i) for i in data)
df[df["score_emoji_tox"]!=0].head()
#df.emojis
#[value for value in df.emojis if value!='']
# Out:
#                                                 texto  toxico  num_admir  \
# 4                                    Ja ja , cabrón 😅       0          0
# 27  El impoluto, según el porcino abrazafarolas de...       1          0
# 58  Pues a mi me parece un tolai, pero vuelvo a de...       1          0
# 86  Amor incondicional en estos animalitos, por al...       0          0
# 87        El amor está en todas partes. 𝒥ℯ𝓁𝒾𝓏 𝒽ℴ𝓎♥︎.        0          0
#
#     num_may                     emojis  num_emoji  num_insultos  dir_23ps  \
# 4         0                          😅          1             1         0
# 27        0  🤣 🐷 🤣 🐷 🤣 🐷 🤣 🐷 🤣 🐷 🤣 🐷 🤣         13             1         0
# 58        0                          😊          1             0         1
# 86        0                          ♥          1             0         1
# 87        0                          ♥          1             0         1
#
#     score_emoji_tox
# 4          0.012000
# 27         0.177769
# 58         0.060000
# 86         0.035000
# 87         0.035000

# %%
df['emojis']=df.emojis.fillna(0)
df.to_csv('res_EDA_Twitter.csv', sep=';', encoding='utf-8')

# %% [markdown]
# **Representación de las categorías **

# %%
#Representación del número de palabras en mayúsuclas
#Se elimina el 0 por no ser siginificativo
dy = sns.countplot(data=df, x='num_may',color=(0.2, 0.4, 0.6),order = list(range(df.num_may.min()+1,6)))
dy.set(xlabel='Número de palabras en mayúsculas', ylabel = 'Número de comentarios')
dy.spines['top'].set_color('none')
dy.spines['right'].set_color('none')
plt.title('Número de palabras en mayúsculas en los tweets')
plt.show()

# %%
#Representación del número de palabras en mayúsuclas
#Se elimina el 0 por no ser siginificativo
dy = sns.countplot(data=df, x='num_admir',color=(0.2, 0.4, 0.6),order = list(range(df.num_admir.min()+1,6)))
dy.set(xlabel='Número de signos de admiración', ylabel = 'Número de comentarios')
dy.spines['top'].set_color('none')
dy.spines['right'].set_color('none')
plt.title('Número de signos de exclamación')
plt.show()

# %%
#Representación del número de palabras etiquetadas como tóxicas
dy = sns.countplot(data=df, x='toxico',color=(0.2, 0.4, 0.6))
dy.set(xlabel='Etiqueta de toxicidad', ylabel = 'Número de comentarios')
dy.spines['top'].set_color('none')
dy.spines['right'].set_color('none')
plt.title('Toxicidad de los comentarios')
plt.show()

# %%
#Representación del número de palabras en mayúsuclas
#Se elimina el 0 por no ser siginificativo
dy = sns.countplot(data=df, x='num_emoji',color=(0.2, 0.4, 0.6),order = list(range(df.num_emoji.min()+1,8)))
dy.set(xlabel='Número de emoticonos', ylabel = 'Número de comentarios')
dy.spines['top'].set_color('none')
dy.spines['right'].set_color('none')
plt.title('Número de emoticonos en los tweets')
plt.show()

# %% [markdown]
# # Wordcloud

# %% [markdown]
# Da una idea generak sobre cuales son las palabras que tienen mas presencia en nuestro corpus.

# %%
forb=stopwords.words('spanish')
forb.append("si")
forb.append("va")
forb.append("el")
forb.append("besugo")
forb.append("bien")
type(forb)
# Out:
# list

# %%
dfwc=df
#Supresión de las stopword en castellano
dfwc['filtered_words']=dfwc.texto.apply(lambda frase: [word.lower() for word in frase.split(' ') if word.lower() not in forb])
#Separación del dataframe en dataframe con lenguaje tóxico y dataframe sin lenguaje tóxico
df_pos=dfwc[dfwc.toxico == 0]
df_neg=dfwc[dfwc.toxico == 1]
#Conversión de la lista de listas a una sola lista con todas las palabras
slist_pos = [st for row in df_pos.filtered_words for st in row]
slist_neg = [st for row in df_neg.filtered_words for st in row]

# %%
#De lista a un string completo
neg_string = ' '.join(slist_neg)
pos_string = ' '.join(slist_pos)

# %%
# Wordcloud de las palabras con significado negativo
wordcloud = WordCloud(width=1400, height=600, max_words=100, \
                      max_font_size=150,\
                      background_color="white",\
                      font_path='C:/Users/Esperanza/Desktop/UOC/TFM/python/Quicksand-Bold.otf').generate(neg_string)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('Top 100 palabras de los comentarios tóxicos', fontsize=20)
plt.show()

# %%
# Wordcloud de las palabras con significado no tóxico
wordcloud = WordCloud(width=1400, height=600, max_words=100, \
                      max_font_size=150,\
                      background_color="white",\
                      font_path='C:/Users/Esperanza/Desktop/UOC/TFM/python/Quicksand-Bold.otf').generate(pos_string)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('Top 100 palabras de los comentarios no tóxicos', fontsize=20)

plt.show()

# %% [markdown]
# ** Bigram**
#
# Debido a  que el orden de las palabras es importante, se comprobará si hay alguno tipo de relación con las palabras que están una junta otra.
#
# Esta función toma una lista de tokens y produce una lista de tuplas con las palabrasque comunmente aparecen una junto a otra.

# %%
import nltk, re, string, collections
from nltk.util import ngrams # function for making ngrams
preposiciones=['a','ante','bajo','cabe','con','contra','de','desde','en','entre','hacia','hasta','para','por','según','sin','so','sobre','tras']
conjunciones=['y', 'en', 'ni', 'o', 'u','mas', 'pero', 'sin embargo', 'no obstante', 'a pesar de', 'aunque']
stop= ['de', 'la','a','en', 'el','y', 'es', 'un','lo','que']
stop=stop+preposiciones+conjunciones

# %%
#Se toma la columna con los textos y se convierte a un string individual if not  if c in
uniendo=[]
[uniendo.append(row+' ') for row in df.texto ]
un_string=','.join(uniendo)
# No se quita mediante stopwords porque hay algunos incluidos en esa lista que se necesitan
un_string=un_string.replace('?', '').replace('¿', '').replace('.', '').replace('', '')\
                    .replace(',', '').replace('!', '').replace('¡', '').replace('”', '').replace('“', '')
res=[word.lower() for word in un_string.split(' ') if word not in stop ]

# %%
res_ngram = ngrams(res, 3)
# Se crea un diccionario collections.Counter que permitirá contras, ver el mínimo el máximo ...
esBigramFreq = collections.Counter(res_ngram)
esBigramFreq.most_common(10)
# Out:
# [(('no', 'se', 'puede'), 12),
#  (('se', 'puede', 'ser'), 12),
#  (('puede', 'ser', 'más'), 10),
#  (('', '', ''), 10),
#  (('data', 'science', ''), 4),
#  (('', 'ofertas', 'trabajo'), 3),
#  (('hijo', 'de', 'puta'), 2),
#  (('son', 'los', 'mismos'), 2),
#  (('porque', 'no', 'se'), 2),
#  (('viva', 'españa', ''), 2)]

# %% [markdown]
# No concluyente, no nos proporciona más información

# %% [markdown]
# **Corrrelación**

# %% [markdown]
# Definida como la asociación/ relación entre variables.
#
#  ** *Covarianza:*  ** Nos puede ayudar a calcular la posible correlación lineal entre las observaciones de dos variables cuantitativas. Primero, cada variable se centra restando su media. Estas puntuaciones centradas se multiplican juntas para medir si el aumento en una variable se asocia con el aumento en otra. Finalmente, el valor esperado (E) del producto de estas puntuaciones centradas se calcula como un resumen de la asociación. Intuitivamente, el producto de las puntuaciones centradas se puede considerar como el área de un rectángulo con la distancia de cada punto de la media que describe un lado del rectángulo.
#                         $$Cov(X, Y) = E $$
#
# El problema con la covarianza es que mantiene la escala de las variables X e Y, y por lo tanto puede tomar cualquier valor. Esto dificulta la interpretación y es imposible comparar covarianzas entre sí. Por ejemplo, Cov (X, Y) = 5.2 y Cov (Z, Q) = 3.1 nos dicen que estos pares están asociados positivamente, pero es difícil decir si la relación entre X e Y es más fuerte que Z y Q sin mirar A los medios y distribuciones de estas variables. Aquí es donde la correlación se vuelve útil: al estandarizar la covarianza mediante alguna medida de variabilidad en los datos, produce una cantidad que tiene interpretaciones intuitivas y una escala consistente.
#
# Fuente: https://www.datascience.com/blog/introduction-to-correlation-learn-data-science-tutorials

# %% [markdown]
# **Coeficiente de correlación de Pearson**

# %% [markdown]
# ** * Pearson* ** es el coeficiente de correlación más usado para medir la asociación entre variables CONTINUAS. Cuantifica el grado en el que la relación entre dos variables puede ser decrita por una linea.
#
# $$ \rho_{X,Y} = \frac{E[(X-\mu_{X})(Y-\mu_{Y})] }{\sigma_{X}\sigma_{Y}}$$
#
# Cuanto más esté ρ a 1, más dependencia hay entre las dos variables y el incremento en una variable resulta en el incremento en otra mientras que si ρ está  cercano a -1 significará que si una varible decrementa resulta en el incremento de la otra variables.

# %%
df.drop(['filtered_words','emojis', 'texto'], axis=1).corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col0 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col1 {
#             background-color:  #85a8fc;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col3 {
#             background-color:  #4961d2;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col4 {
#             background-color:  #eed0c0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col5 {
#             background-color:  #5a78e4;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col6 {
#             background-color:  #455cce;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col0 {
#             background-color:  #6687ed;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col1 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col2 {
#             background-color:  #4c66d6;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col3 {
#             background-color:  #3f53c6;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col5 {
#             background-color:  #3c4ec2;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col6 {
#             background-color:  #455cce;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col1 {
#             background-color:  #6c8ff1;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col2 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col3 {
#             background-color:  #5673e0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col4 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col5 {
#             background-color:  #6788ee;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col6 {
#             background-color:  #5a78e4;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col1 {
#             background-color:  #506bda;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col2 {
#             background-color:  #465ecf;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col3 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col4 {
#             background-color:  #4b64d5;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col5 {
#             background-color:  #516ddb;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row3_col6 {
#             background-color:  #b7cff9;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col0 {
#             background-color:  #eed0c0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col1 {
#             background-color:  #5a78e4;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col3 {
#             background-color:  #5a78e4;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col4 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col5 {
#             background-color:  #5f7fe8;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row4_col6 {
#             background-color:  #4f69d9;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col1 {
#             background-color:  #3c4ec2;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col2 {
#             background-color:  #465ecf;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col3 {
#             background-color:  #4055c8;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col4 {
#             background-color:  #3f53c6;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col5 {
#             background-color:  #b40426;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row5_col6 {
#             background-color:  #455cce;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col0 {
#             background-color:  #3b4cc0;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col1 {
#             background-color:  #5977e3;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col2 {
#             background-color:  #4f69d9;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col3 {
#             background-color:  #bad0f8;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col4 {
#             background-color:  #4358cb;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col5 {
#             background-color:  #5977e3;
#         }    #T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >toxico</th>
#         <th class="col_heading level0 col1" >num_admir</th>
#         <th class="col_heading level0 col2" >num_may</th>
#         <th class="col_heading level0 col3" >num_emoji</th>
#         <th class="col_heading level0 col4" >num_insultos</th>
#         <th class="col_heading level0 col5" >dir_23ps</th>
#         <th class="col_heading level0 col6" >score_emoji_tox</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3level0_row0" class="row_heading level0 row0" >toxico</th>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col1" class="data row0 col1" >0.12</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col2" class="data row0 col2" >-0.14</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col3" class="data row0 col3" >-0.081</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col4" class="data row0 col4" >0.52</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col5" class="data row0 col5" >-0.022</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row0_col6" class="data row0 col6" >-0.095</td>
#     </tr>    <tr>
#         <th id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3level0_row1" class="row_heading level0 row1" >num_admir</th>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col0" class="data row1 col0" >0.12</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col2" class="data row1 col2" >0.039</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col3" class="data row1 col3" >-0.0031</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col4" class="data row1 col4" >-0.022</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col5" class="data row1 col5" >-0.015</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row1_col6" class="data row1 col6" >0.014</td>
#     </tr>    <tr>
#         <th id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3level0_row2" class="row_heading level0 row2" >num_may</th>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col0" class="data row2 col0" >-0.14</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col1" class="data row2 col1" >0.039</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col2" class="data row2 col2" >1.0</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col3" class="data row2 col3" >-0.036</td>
#         <td id="T_f34d6fcc_9365_11e9_9678_34e6ad9edaf3row2_col4" class="data row2 col4" >-0

# %%
# plot correlated values
#plt.rcParams['figure.figsize'] = [16, 6]

fig, ax = plt.subplots(nrows=1, ncols=3)

ax=ax.flatten()

cols = ['num_admir', 'num_may', 'num_insultos' ]
colors=['#415952', '#f35134', '#243AB5', '#243AB5']
j=0

for i in ax:
    if j==0:
        i.set_ylabel('toxico')
    i.scatter(df[cols[j]], df['toxico'],  alpha=0.5, color=colors[j])
    i.set_xlabel(cols[j])
    i.set_title('Pearson: %s'%df.corr().loc[cols[j]]['toxico'].round(2)+' Spearman: %s   '%df.corr(method='spearman').loc[cols[j]]['toxico'].round(3), fontsize=7)
    j+=1

plt.title('Coeficiente de correlación de Pearson y Spearman', fontsize=20, y=1.10, x=-1)
plt.show()

# %% [markdown]
# # Lemmatization

# %%
from spacy.lang.es import Spanish
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9552af19f594> in <module>()
# ----> 1 from spacy.lang.es import Spanish
#
# ModuleNotFoundError: No module named 'spacy'

# %%
import spacy
nlp = spacy.load('es_core_news_sm')  # same behaviour with spacy.blank('es')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-37521609df45> in <module>()
# ----> 1 import spacy
#       2 nlp = spacy.load('es_core_news_sm')  # same behaviour with spacy.blank('es')
#
# ModuleNotFoundError: No module named 'spacy'

# %%
text1 = "Con estos fines, la Dirección de Gestión y Control Financiero monitorea la posición de capital del Banco y utiliza los mecanismos para hacer un eficiente manejo del capital."
for token in nlp(text1):
    print(token.text, token.lemma_, token.pos_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-392fc1124e83> in <module>()
#       1 text1 = "Con estos fines, la Dirección de Gestión y Control Financiero monitorea la posición de capital del Banco y utiliza los mecanismos para hacer un eficiente manejo del capital."
# ----> 2 for token in nlp(text1):
#       3     print(token.text, token.lemma_, token.pos_)
#
# NameError: name 'nlp' is not defined

# %%
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])

# %%
# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

# %%
Cosas que sigo queriendo hacer: 
    https://marcobonzanini.com/2015/04/01/mining-twitter-data-with-python-part-5-data-visualisation-basics/ 
        (Preparion for data visualisation)
        que pareece que es lo mismo que el final de https://towardsdatascience.com/another-twitter-sentiment-analysis-with-python-part-2-333514854913
eres excepcionalmente idiota
# Out:
#   File "<ipython-input-49-1355e03f620f>", line 3
#     Cosas que sigo queriendo hacer:
#             ^
# SyntaxError: invalid syntax
